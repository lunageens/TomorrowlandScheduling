# %%
# TODO Problem Descrip -- moet beter; nog meer research based.
# TODO Including Genres -- perhaps as extension? Or own planning of the schedule?

# %% [markdown]
# # Tomorrowland Artist Scheduling
# *Vlerick Business School, Master in Data Analytics and Artificial Intelligence 2024-2025. Made by Luna Geens. For the course Decision Optimisation given by Mario Vanhoucke, as a final assignment due on Friday 20 Dec 2024.*

# %% [markdown]
# <br>
#
# ----
#
# <br>

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# ###  <b style="color: #8B0000;">1.1 Problem Description</b>

# %% [markdown]
# Tomorrowland, as one of the largest and most prestigious electronic music festivals globally, attracts hundreds of thousands of attendees from over **200 countries**, with tickets often selling out within minutes. Since its founding in **2005**, Tomorrowland has expanded to host over **15 stages** simultaneously, accommodating **800+ artists** across multiple weekends, making efficient scheduling a necessity rather than a choice.
#
# Efficient artist scheduling is not only a logistical challenge, but also a critical factor in enhancing the **festival experience** and **business outcomes**.
# - Festivals thrive on providing unforgettable experiences, where attendees expect their favorite artists to perform at ideal times and on prominent stages. Balancing artist popularity with time slots ensures maximum audience engagement and satisfaction.
# -  Strategic artist placement directly influences festival success:
#      - Ticket Sales: Scheduling popular artists during prime slots drives higher attendance.
#      - Reputation: Delivering a seamless experience strengthens Tomorrowland's global standing as a premier festival.
#      - Cost Optimization: Efficient scheduling minimizes operational costs related to stage management, logistics, and artist coordination.
#
# <br>
#
# Tomorrowland’s scale introduces significant complexity:
#
# - High Artist Volume: Hundreds of artists perform multiple sets across various stages over several days.
# - Time and Stage Constraints: Each stage has a defined availability window per day, while artists have specific limits on the number of performances and required rest time.
# - Audience Demand: Aligning artist popularity with desirable time slots adds another layer of optimization.
#
# <Br>
#
# At Tomorrowland's scale, manual scheduling is impractical. By leveraging optimizatoin-driven approaches, this research provides insights into optimizing festival scheduling, delivering tangible benefits to both attendees and organizers. In recent years, studies on festival optimization have increasingly relied on **mathematical models** (e.g., linear programming) to address these challenges.

# %% [markdown]
# ###  <b style="color: #8B0000;">1.2 Mathematical Problem Description</b>

# %% [markdown]
# #### <b style="color: #8B0000;">1.2.1 Input Sets and Parameters</b>

# %% [markdown]
# Sets:
# - $S$ = Set of **stages**, where $S = { s_1, s_2, \dots, s_n } $.
# - $A$ = Set of **artists**, where $ A = { a_1, a_2, \dots, a_m} $.
# - $K_a$ = Set of **sets performed** by artist $ a \in A$, where $K_a = {k_1, k_2, \dots , k_l}$ .
# - $D$ = Set of **days**, where $D={D=a_1, a_2, \dots, a_p}$.
# - $T_s,d$ = Set of **starting points of time slots** available for stage $s$ during day $d$, where $T_{s,d} = {t_1, t_2, \dots, t_q}$.

# %% [markdown]
# Parameters:
#
# **Set-Specific** Parameters: For each artist's set $k \in K_a $:
# - $b_{k}$: Time point in minutes of the beginning of the set $k$. *Note that this is a decision variable in the problem, not a parameter!*
# - $d_{k}$: Day of the set $k$.
# - $e_{k} $: Duration of set $ k $ in minutes.
#
# **Stage-Specific** Parameters: For each stage $s \in S $:
# - $t^{open}_{s,d}$: Opening time of stage $s$ on day $d$.
# - $t^{close}_{s,d}$: Closing time of stage $s$ on day $d$.
# - $c$: Clean-up time required after a performance on each stage (e.g., $ c = 45  \text{ minutes} $).
#
# **Artist-Specific** Parameters: For each artist $a \in A$:
# - $r$:  Rest time required for each artist between two sets (e.g., $ r = 120  \text{ minutes} $).
# - $ \text{max\_sets}$: Maximum number of performances each artist can play per day. (e.g., $ \text{max\_sets} = 2 $).
#
# **Popularity** Parameters:
# - $ p_a $: Popularity score for artist $ a $, where $ a \in A $.
# - $ p_s $: Popularity score for stage $ s $, where $ s \in S $.
# - $ p_t $: Weight indicating the popularity of the starting point of the timeslot $ t $, where $ t \in T $.
#
# <br>

# %% [markdown]
# #### <b style="color: #8B0000;">1.2.2 Decision Variables</b>

# %% [markdown]
# The decision variable accounts for artists performing multiple sets:
#
# $
#     x_{a, k, s, d, t} =
# \begin{cases}
# 1 & \text{if artist } a \text{ performs set } k \text{ on stage } s \text{ starting at time slot } t \text{ on day } d \\
#     0 & \text{otherwise.}
# \end{cases}
# $
#
# Where:
# - $ a \in A $: Artist in the set of  Artists.
# - $ k \in K_a $: Set in the set of Sets performed by artist $a$.
# - $ s \in S $: Stage in the set of Stages.
# - $ t \in T_{s,d} $: Start time in the set of Start times for stage $s$ on day $d$.
# - $ d \in D$: Day in the set of Days.
#
# <br>

# %% [markdown]
# #### <b style="color: #8B0000;">1.2.3 Objective Function</b>

# %% [markdown]
# The objective is to **maximize customer satisfaction** by considering artist, stage, and timeslot popularity. These weights are predefined inputs based on audience preferences or prior analysis.
#
# $
# \text{Maximize } Z = \sum_{a \in A} \sum_{k \in K_a} \sum_{s \in S} \sum_{d \in D} \sum_{t \in T_{s,d}} (\alpha \cdot p_{a} + \beta \cdot p_{s} + \gamma \cdot p_{t}) \cdot x_{a, k, s, d, t}.
# $
#
# Where:
# - $ a \in A $: Artist in the set of  Artists.
# - $ k \in K_a $: Set in the set of Sets performed by artist $a$.
# - $ s \in S $: Stage in the set of Stages.
# - $ t \in T_{s,d} $: Start time in the set of Start times for stage $s$ on day $d$.
# - $ d \in D$: Day in the set of Days.
# - $ p_a $: Popularity score for artist $ a $, where $ a \in A $.
# - $ p_s $: Popularity score for stage $ s $, where $ s \in S $.
# - $ p_t $: Popularity score of the starting point of the timeslot $ t $, where $ t \in T_{s,d}$.
# - $ \alpha, \beta, \gamma$: Weigths indicating the relative importance of artists, stage, and timeslot popularity,
# - $x_{a, k, s, d, t}$: Binary variable indicating if artist $a$ performs set $k$ on stage $s$ starting at time slot $t$ on day $d$.
#
# <br>

# %% [markdown]
# #### <b style="color: #8B0000;">1.2.4 Constraints</b>

# %% [markdown]
# **(1) Each Set is Scheduled Exactly Once.**
#
# Each set $ k $ of artist $ a $ must be scheduled at exactly one stage and time (timeslot and day):
#
# For $\forall a \in A; \ k \in K_{a}$:
#
# $
# \sum_{s \in S} \sum_{d \in D} \sum_{t \in T_{s,d}}  x_{a, k, s, d, t} = 1
# $.
#
# Where:
# - $ a \in A $: Artists.
# - $ k \in K_a $: Sets performed by artist $a$.
# - $ s \in S $: Stages.
# - $ d \in D$: Days.
# - $ t \in T_{s,d} $: Start times for stage $s$ on day $d$.
# - $x_{a, k, s, d, t}$: Binary variable indicating if artist $a$ performs set $k$ on stage $s$ starting at time slot $t$ on day $d$.
#
# <br>

# %% [markdown]
# **(2) Each Set is Scheduled within Stage Availability.**
#
# The start and end times of each set $k$ of artist $a$ played on stage $s$ on a day $d$ must lie within the stage’s open and close times of that day $d$.
#
# For $\forall s \in S; \ d \in D; \ a \in A; \ k \in K_a$: Both conditions (1) and (2) are required to hold.
#
# 1. Start time $b_{k}$ of set $k$ on stage $s$ is after the stage's opening time $t^{open}_{s,d}$: $ \ b_{k} \leq t^{open}_{s,d}$.
# 2. The set finishes ($b_{k} + e_k$) before the stage's closing time $t^{close}_{s,d}$: $ \ b_{k} + e_{k} \leq t^{close}_{s,d}$.
#
# Where:
# - $ s \in S $: Stages.
# - $ d \in D$: Days.
# - $ a \in A $: Artists.
# - $ k \in K_a $: Sets performed by artist $a$.
# - $b_{k}$: Time point in minutes of the beginning of the set $k$.
# - $e_k$: Duration of set $ k $ in minutes.
# - $t^{open}_{s,d}$: Opening time of stage $s$ on day $d$.
# - $t^{close}_{s,d}$: Closing time of stage $s$ on day $d$.
#
# <br>

# %% [markdown]
# **(3) Sets on the Same Stage are Scheduled at a Different Time with a Clean-Up Time inbetween.**
#
# Two sets $k$ and $k′$ on the same stage $s$ do not overlap in time.  Additionally, a clean-up time $c$ is required between the two sets. This ensures that no two performances occur simultaneously on the same stage, and sufficient time is allowed for stage preparation between sets.
#
# For $\forall s \in S$; $d \in D$; $a \in A$;  $k, k' \in K_a$ and $k \neq k' $: At least one of the conditions (1) and (2) are required to hold.
#
# 1. Set $k$ must finish before $k′$ starts: $b_k + e_k + c \leq b'_k$.
# 2. Set $k′$ must finish before $k$ starts: $b'_k + e'_k + c \leq b_k$.
#
# Where:
# - $ s \in S $: Stages.
# - $ d \in D$: Days.
# - $ a \in A $: Artists.
# - $ k \in K_a $: Sets performed by artist $a$.
# - $b_{k}$: Time point in minutes of the beginning of the set $k$.
# - $e_k$: Duration of set $ k $ in minutes.
# - $c$: Clean-up Time $(c = 45  \text{ minutes} )$.
#
# <br>

# %% [markdown]
# **(4) Sets of the Same Artist are Scheduled at a Different Time with a Rest Time inbetween.**
#
# Two sets $k$ and $k′$ of the same artist $a$ do not overlap in time.  Additionally, a rest time $r$ is required between the two sets. This ensures that no two performances occur simultaneously of the same artist, and sufficient time is allowed for artist preparation between sets.
#
# For $\forall s, s' \in S$; $d \in D$; $a \in A$;  $k, k' \in K_a$ and $k \neq k' $: At least one of the conditions (1) and (2) are required to hold.
#
# 1. Set $k$ must finish before $k′$ starts: $b_k + e_k + r \leq b'_k$.
# 2. Set $k′$ must finish before $k$ starts: $b'_k + e'_k + r \leq b_k$.
#
# Where:
# - $ s, s' \in S $: Stages. The sets can be on the same or different stages.
# - $ d \in D$: Days.
# - $ a \in A $: Artists.
# - $ k \in K_a $: Sets performed by artist $a$.
# - $b_{k}$: Time point in minutes of the beginning of the set $k$.
# - $e_k$: Duration of set $ k $ in minutes.
# - $r$: Rest Time $(r = 120  \text{ minutes} )$.
#
# <br>

# %% [markdown]
# **(5) No more than 2 Sets of an Artist are Scheduled on the Same Day.**
#
# Each artist is restricted to performing at most two sets on any single day. This ensures a manageable workload and a balanced schedule.
#
# For $d \in D$; $a \in A$:
#
# $\sum_{k \in K_a} \sum_{s \in S} \sum_{t \in T_{s,d}} x_{a, k, s, d, t} \leq 2$
#
# Where:
# - $ d \in D$: Days.
# - $ a \in A $: Artists.
# - $ k \in K_a $: Sets performed by artist $a$.
# - $ s \in S $: Stages.
# - $ t \in T_{s,d} $: Start times for stage $s$ on day $d$.
# - $x_{a, k, s, d, t}$: Binary variable indicating if artist $a$ performs set $k$ on stage $s$ starting at time slot $t$ on day $d$.
#
# <br>

# %% [markdown]
# <b style="color: #8B0000;">5. Outputs</b>
#
# The solution will provide:
# 1. **Artist Schedule**: Table mapping each artist's set to a stage, time, and day.
# 2. **Stage Utilization**: Ensures clean-up time is respected between sets.
# 3. **Artist Rest Validation**: Verifies artists have sufficient rest and do not exceed two sets per day.
# 4. **Stage Availability**: Summarizes the overall availability for each stage.
#
# <br>

# %% [markdown]
# <b style="color: #8B0000;">6. Summary Table of Symbols</b>
#
# | **Symbol**                 | **Description**                                                                                                             |
# |----------------------------|-----------------------------------------------------------------------------------------------------------------------------|
# | $S$                        | Set of stages, where $S = \{s_1, s_2, \dots, s_n\} $.                                                                       |
# | $A$                        | Set of artists, where $ A = \{a_1, a_2, \dots, a_m\} $.                                                                     |
# | $ K_a $                  | Set of sets performed by artist $ a \in A $, $ K_a = \{k_1, k_2, \dots, k_l\} $.                                            |
# | $ D $                    | Set of days, where $ D = \{d_1, d_2, \dots, d_p\} $.                                                                        |
# | $ T_{s,d} $              | Set of starting points of time slots available for stage $ s $ during day $ d $.                                            |
# | $ b_k $                  | Time point in minutes of the beginning of the set $ k $.                                                                    |
# | $ d_k $                  | Day of the set $ k $.                                                                                                       |
# | $ e_k $                  | Duration of set $ k $ in minutes.                                                                                           |
# | $ t^{open}_{s,d} $       | Opening time of stage $ s $ on day $ d $.                                                                                   |
# | $ t^{close}_{s,d} $      | Closing time of stage $ s $ on day $ d $.                                                                                   |
# | $ c $                    | Clean-up time required after a performance on each stage.                                                                   |
# | $ r $                    | Rest time required for each artist between two sets.                                                                        |
# | $ \text{max\_sets} $     | Maximum number of performances each artist can play per day.                                                                |
# | $ p_a $                  | Popularity score for artist $ a $.                                                                                          |
# | $ p_s $                  | Popularity score for stage $ s $.                                                                                           |
# | $ p_t $                  | Popularity of the starting point of the timeslot $ t $.                                                                     |
# | $ \alpha, \beta, \gamma $ | Weights indicating the importance of artist, stage, and timeslot popularity.                                                |
# | $ x_{a, k, s, d, t} $    | Binary variable: 1 if artist $ a $ performs set $ k $ on stage $ s $ starting at time slot $ t $ on day $ d $, 0 otherwise. |
#
#
# <br>

# %% [markdown]
# <br>
#
# ----
#
# <br>

# %% [markdown]
# ## 2. Data Imports

# %%
# * All imports
import pulp
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
import spotipy
from spotipy.oauth2 import SpotifyOAuth
import re
import time  # For handling delays
import csv

# %% [markdown]
# ###  <b style="color: #8B0000;">2.1 Getting the data</b>

# %% [markdown]
# ####  <b style="color: #8B0000;">2.1.1 Web Scraping Line-up Information</b>

# %% [markdown]
# First, we need to collect some data on the artists. This process involves gathering and organizing Tomorrowland 2024's timetable directly from the web. The schedule is extracted from [an online page providing information on timetables of different festivals](https://festivalviewer.com/tomorrowland/lineup/2024), structured into a table format, and saved as a CSV file. This makes sure that next year, we can reuse the code.

# %%
# * Scrape the web for the timetable of Tomorrowland 2024
#
# # URL of the Tomorrowland Lineup Page
# url = 'https://festivalviewer.com/tomorrowland/lineup/2024'
#
# # Fetch the page content
# response = requests.get(url)
# soup = BeautifulSoup(response.content, 'html.parser')
#
# # Find the table containing the lineup data
# table = soup.find('table', {'id': 'table_id'})
#
# # Extract table headers
# headers = [th.text.strip() for th in table.find('thead').find_all('th')]
#
# # Extract rows directly without 'tbody'
# rows = []
# for tr in table.find_all('tr'):  # Find all rows in the table
#     td_elements = tr.find_all('td')  # Find all data cells
#     if td_elements:  # Only process rows with <td> elements
#         row = [td.text.strip() for td in td_elements]
#         rows.append(row)
#
# # Convert to DataFrame
# lineup_df = pd.DataFrame(rows, columns=headers)
#
# # Save to CSV
# lineup_df.to_csv('doc/tomorrowland_lineup_2024.csv', index=False)
# print("Data saved to tomorrowland_lineup_2024.csv")
#
# lineup_df
# Out:
# Data saved to tomorrowland_lineup_2024.csv
#                         Artist     Stage Name  \
# 0                      DJ Mars  The Gathering
# 1                       Bosart  The Gathering
# 2                       Dietro  The Gathering
# 3                      Voltage  The Gathering
# 4                       Elfigo  The Gathering
# ..                         ...            ...
# 815                 Da Tweekaz    Rose Garden
# 816                      MANDY    Rose Garden
# 817                 Tweekacore    Rose Garden
# 818  Mark with a K & Mc Chucky    Rose Garden
# 819                   Aversion    Rose Garden
#
#                              Host Name       Timeslot     Date  Year  \
# 0    The Gathering hosted by MC Gunner  13:30 - 14:15  18 July  2024
# 1    The Gathering hosted by MC Gunner  14:15 - 15:00  18 July  2024
# 2    The Gathering hosted by MC Gunner  15:00 - 15:45  18 July  2024
# 3    The Gathering hosted by MC Gunner  15:45 - 16:30  18 July  2024
# 4    The Gathering hosted by MC Gunner  16:30 - 17:15  18 July  2024
# ..                                 ...            ...      ...   ...
# 815                        Tweekamania  17:00 - 18:00  28 July  2024
# 816                        Tweekamania  18:00 - 19:00  28 July  2024
# 817                        Tweekamania  19:00 - 20:00  28 July  2024
# 818                        Tweekamania  20:00 - 21:00  28 July  2024
# 819                        Tweekamania  21:00 - 22:00  28 July  2024
#
#           Day    Weekend              Genre(s)
# 0    Thursday  Weekend 1
# 1    Thursday  Weekend 1
# 2    Thursday  Weekend 1
# 3    Thursday  Weekend 1
# 4    Thursday  Weekend 1
# ..        ...        ...                   ...
# 815    Sunday  Weekend 2       Hardcore Techno
# 816    Sunday  Weekend 2            Hard Dance
# 817    Sunday  Weekend 2
# 818    Sunday  Weekend 2  Jumpstyle, Hardstyle
# 819    Sunday  Weekend 2
#
# [820 rows x 9 columns]

# %% [markdown]
# ####  <b style="color: #8B0000;">2.1.2 Web Scraping Artist Information</b>

# %% [markdown]
# This code retrieves artist data, including their popularity score, from Spotify Developer Platform. The popularity score is a value between 0 and 100 that reflects an artist's global appeal, based on factors such as streaming activity and audience engagement. This metric provides a quantitative measure of an artist's popularity, which can be used to prioritize performances and optimize scheduling for maximum audience satisfaction.

# %%
# Spotify API credentials
# client_id = "8e48f7e04b65411b841111071db3137e"
# client_secret = "511c136e11dd46938a8d8b7581bb6ff9"
# redirect_uri = "http://localhost:8080/callback"
#
# # Define the scope to read artist data
# scope = "user-read-private"
#
# # Authenticate with Spotify
# sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=client_id,
#                                                client_secret=client_secret,
#                                                redirect_uri=redirect_uri,
#                                                scope=scope))
#
# # Function to get artist popularity
# def get_artist_popularity(artist_name):
#     results = sp.search(q=f"artist:{artist_name}", type="artist", limit=1)
#     if results['artists']['items']:
#         artist = results['artists']['items'][0]
#         return {
#             "name": artist['name'],
#             "popularity": artist['popularity'],
#             "genres": artist['genres']
#         }
#     return None
#
# # Example usage
# a = "Amy Winehouse"
# artist_info = get_artist_popularity(a)
#
# if artist_info:
#     print(f"Artist: {artist_info['name']}")
#     print(f"Popularity: {artist_info['popularity']}")
#     print(f"Genres: {', '.join(artist_info['genres'])}")
# else:
#     print("Artist not found.")
# Out:
# Artist: Amy Winehouse
# Popularity: 80
# Genres: british soul, neo soul

# %% [markdown]
# ###  <b style="color: #8B0000;">2.2 Constructing Data Variables</b>

# %% [markdown]
# ####  <b style="color: #8B0000;">2.2.1 From Line-up Information</b>

# %%
# * Load Data
file_path = 'doc/tomorrowland_lineup_2024.csv'
lineup_df = pd.read_csv(file_path)

# %% [markdown]
# First, we will put the time in a correct format and create the start, end and duration time of each set:

# %%
# * Combine Year, Date, and Timeslot for Start and End Times as well as Duration
def parse_and_adjust_day(row):
    try:
        # Parse Start and End Times
        start_time = pd.to_datetime(
            f"{row['Year']} {row['Date']} {row['Timeslot'].split('-')[0].strip()}",
            format='%Y %d %B %H:%M'
        )
        end_time = pd.to_datetime(
            f"{row['Year']} {row['Date']} {row['Timeslot'].split('-')[1].strip()}",
            format='%Y %d %B %H:%M'
        )

        # Adjust for midnight crossover
        if end_time < start_time:
            end_time += pd.Timedelta(days=1)

        # Adjust Day_Combined_ID if set occurs entirely after midnight
        # Assume the festival day ends at 6 AM
        if start_time.hour >= 0 and start_time.hour < 6:
            adjusted_day = row['Day_Combined_ID'] - 1  # Attribute it to the previous day
        else:
            adjusted_day = row['Day_Combined_ID']  # Keep the current day

        return start_time, end_time, adjusted_day
    except Exception as e:
        print(f"Error processing row {row}: {e}")
        return pd.NaT, pd.NaT, row['Day_Combined_ID']


# Apply parsing logic
lineup_df[['Start Time', 'End Time', 'Adjusted Day']] = lineup_df.apply(
    lambda row: pd.Series(parse_and_adjust_day(row)), axis=1
)

# Step 3: Calculate Duration
lineup_df['Duration (minutes)'] = (lineup_df['End Time'] - lineup_df['Start Time']).dt.total_seconds() / 60

# %%
# * Create Unique Day IDs
# Combine 'Day' and 'Weekend' to create a unique identifier for each combination
lineup_df['Day_Combined'] = lineup_df['Day'] + " " + lineup_df['Weekend']
# Generate unique IDs for each combination
lineup_df['Day_Combined_ID'] = lineup_df['Day_Combined'].astype('category').cat.codes + 1

# %%
# * Create unique set numbers
lineup_df['Set_ID'] = lineup_df.groupby('Artist').cumcount() + 1

# %%
# * Display Results
print("Cleaned Lineup Data:")
lineup_df
# Out:
# Cleaned Lineup Data:
#                         Artist     Stage Name  \
# 0                      DJ Mars  The Gathering
# 1                       Bosart  The Gathering
# 2                       Dietro  The Gathering
# 3                      Voltage  The Gathering
# 4                       Elfigo  The Gathering
# ..                         ...            ...
# 815                 Da Tweekaz    Rose Garden
# 816                      MANDY    Rose Garden
# 817                 Tweekacore    Rose Garden
# 818  Mark with a K & Mc Chucky    Rose Garden
# 819                   Aversion    Rose Garden
#
#                              Host Name       Timeslot     Date  Year  \
# 0    The Gathering hosted by MC Gunner  13:30 - 14:15  18 July  2024
# 1    The Gathering hosted by MC Gunner  14:15 - 15:00  18 July  2024
# 2    The Gathering hosted by MC Gunner  15:00 - 15:45  18 July  2024
# 3    The Gathering hosted by MC Gunner  15:45 - 16:30  18 July  2024
# 4    The Gathering hosted by MC Gunner  16:30 - 17:15  18 July  2024
# ..                                 ...            ...      ...   ...
# 815                        Tweekamania  17:00 - 18:00  28 July  2024
# 816                        Tweekamania  18:00 - 19:00  28 July  2024
# 817                        Tweekamania  19:00 - 20:00  28 July  2024
# 818                        Tweekamania  20:00 - 21:00  28 July  2024
# 819                        Tweekamania  21:00 - 22:00  28 July  2024
#
#           Day    Weekend              Genre(s)          Start Time  \
# 0    Thursday  Weekend 1                   NaN 2024-07-18 13:30:00
# 1    Thursday  Weekend 1                   NaN 2024-07-18 14:15:00
# 2    Thursday  Weekend 1                   NaN 2024-07-18 15:00:00
# 3    Thursday  Weekend 1                   NaN 2024-07-18 15:45:00
# 4    Thursday  Weekend 1                   NaN 2024-07-18 16:30:00
# ..        ...        ...                   ...                 ...
# 815    Sunday  Weekend 2       Hardcore Techno 2024-07-28 17:00:00
# 816    Sunday  Weekend 2            Hard Dance 2024-07-28 18:00:00
# 817    Sunday  Weekend 2                   NaN 2024-07-28 19:00:00
# 818    Sunday  Weekend 2  Jumpstyle, Hardstyle 2024-07-28 20:00:00
# 819    Sunday  Weekend 2                   NaN 2024-07-28 21:00:00
#
#                End Time  Duration (minutes)        Day_Combined  \
# 0   2024-07-18 14:15:00                45.0  Thursday Weekend 1
# 1   2024-07-18 15:00:00                45.0  Thursday Weekend 1
# 2   2024-07-18 15:45:00                45.0  Thursday Weekend 1
# 3   2024-07-18 16:30:00                45.0  Thursday Weekend 1
# 4   2024-07-18 17:15:00                45.0  Thursday Weekend 1
# ..                  ...                 ...                 ...
# 815 2024-07-28 18:00:00                60.0    Sunday Weekend 2
# 816 2024-07-28 19:00:00                60.0    Sunday Weekend 2
# 817 2024-07-28 20:00:00                60.0    Sunday Weekend 2
# 818 2024-07-28 21:00:00                60.0    Sunday Weekend 2
# 819 2024-07-28 22:00:00                60.0    Sunday Weekend 2
#
#      Day_Combined_ID  Set_ID
# 0                  7       1
# 1                  7       1
# 2                  7       1
# 3                  7       1
# 4                  7       1
# ..               ...     ...
# 815                6       2
# 816                6       2
# 817                6       1
# 818                6       1
# 819                6       1
#
# [820 rows x 15 columns]

# %% [markdown]
# Then we can use this to create the stage availability for each stage on each day:

# %%
# Step 5: Prepare Stage Availability Windows
stage_availability = lineup_df.groupby(['Stage Name', 'Day_Combined_ID']).agg({
    'Start Time': 'min',
    'End Time': 'max'
}).reset_index()

print("\nStage Availability:")
stage_availability
# Out:
# Stage Availability:
#        Stage Name  Day_Combined_ID          Start Time            End Time
# 0      Atmosphere                1 2024-07-19 12:00:00 2024-07-20 00:55:00
# 1      Atmosphere                2 2024-07-26 12:00:00 2024-07-27 00:55:00
# 2      Atmosphere                3 2024-07-20 00:00:00 2024-07-21 00:00:00
# 3      Atmosphere                4 2024-07-27 00:00:00 2024-07-28 00:00:00
# 4      Atmosphere                5 2024-07-21 12:00:00 2024-07-21 23:55:00
# ..            ...              ...                 ...                 ...
# 87    Rose Garden                4 2024-07-27 13:00:00 2024-07-28 01:00:00
# 88    Rose Garden                5 2024-07-21 13:00:00 2024-07-21 23:00:00
# 89    Rose Garden                6 2024-07-28 13:00:00 2024-07-28 23:00:00
# 90  The Gathering                7 2024-07-18 13:30:00 2024-07-19 00:00:00
# 91  The Gathering                8 2024-07-25 13:30:00 2024-07-26 00:00:00
#
# [92 rows x 4 columns]

# %%
# Create list of artist
A = lineup_df['Artist'].unique().tolist()

# %% [markdown]
# ####  <b style="color: #8B0000;">2.2.2 From Artist Information</b>

# %% [markdown]
# Let's now look into the popularity scores.

# %%
# * Get popularity scores of artists
# # ! Limitation: Cannot find popularity score for 10% of artists (mostly DJs with no own numbers); assigned a popularity score of 50
# # Initialize a dictionary to store artist popularity
# p_a = {}
# failed_artists = []  # List to track artists for whom all attempts failed

# %%
# Helper function to clean up artist names and extract parts
# def extract_artist_parts(artist_name):
#     """
#     Split artist names into parts, e.g., for 'Artist_1 ft Artist_2 & Friends':
#     Return a list: ['Artist_1', 'Artist_2', 'Friends']
#     """
#     # Use regex to split on 'ft', 'b2b', '&', ',', and parentheses
#     parts = re.split(r'ft|b2b|&|,|\(|\)', artist_name)
#     return [part.strip() for part in parts if part.strip()]  # Remove empty parts

# %%
# Loop through each artist to get their popularity
# for a in A:
#     try:
#         # First attempt: Full artist name
#         artist_info = get_artist_popularity(a)
#         if artist_info:
#             p_a[a] = artist_info['popularity']
#             continue  # Move to the next artist if found
#
#         # If not found, split the artist name and try each part
#         artist_parts = extract_artist_parts(a)
#
#         # Sequentially try each artist part
#         found = False
#         for part in artist_parts:
#             artist_info_part = get_artist_popularity(part)
#             if artist_info_part:
#                 p_a[a] = artist_info_part['popularity']
#                 found = True
#                 break  # Stop as soon as one part succeeds
#
#             # Optional: Add a short delay to avoid hitting API rate limits
#             time.sleep(0.1)
#
#         if not found:
#             # If all attempts fail, assign default popularity and record the artist
#             p_a[a] = 50
#             failed_artists.append(a)
#
#     except Exception as e:
#         # Handle API errors or other issues
#         p_a[a] = 0
#         failed_artists.append(a)
#         print(f"Error fetching popularity for {a}: {e}")

# %%
# # Print only the failed artists
# print("\nArtists for whom all fallback attempts failed (" + str(len(failed_artists)) + "):")
# print(failed_artists)
#
# # Print the resulting popularity dictionary
# print("\nFinal Artist Popularity (" + str(len(p_a)) + " artists, default popularity of 50 if not found):")
# print(p_a)
# Out:
# Artists for whom all fallback attempts failed (69):
# ['>rthur Lewis ft. Gerben Tuerlinckx', 'Q DANCE End show', 'Daybreak Session: Oliver Heldens', 'Kamal Bankay', 'Thierry VonderWarth', 'Piaggio Disco Club', 'Stasi Sanlin', 'Milan Evens', 'Schuurrallures', 'Deuxfwa', 'Stephine B', 'Symphony of Unity', 'Juul Pence', 'Daybreak Session: Laidback Luke presents Wayback Luke', 'Naomi Cazier', 'DJ Señor Funk', 'Jerrooo', 'Tobi Trekhaak', 'Hollaback Soundystem', 'Mariah Curry', 'Olsan Twins', 'Discobaar A Moeder', 'Gomorris', 'Lucca van Damme', 'Daybreak Session: One World Radio Soundsystem', 'Frank Mellemans', 'Mad Maxx vs Stryker', 'Delafino B2B DJ Gee', 'Niki August', 'Sako Glitch', 'Medaase', 'Nederhand', 'Lovelee Days', 'Noaffection', 'D. Guaetta', 'Surprise Vinyl only set', 'Lilihell', 'Tous Les Deux', 'DJ Chanelle', 'FlavãSoul Soundsystem', 'Flavour Drop', 'Tom Cosyns', 'JUSTANOTHERDJ', 'Bram Delux', 'PartyShakerz', 'Winterclubbing All Stars', 'Ellli Acula', 'So Blonde Sound System', 'Daybreak session: Laidback Luke presents Wayback Luke', 'Bibi Seck', 'Jeremy Underground', 'Pauline Noyen', 'Annabel Stop It', 'Zoe Hasselbank', 'Hangar Soundsystem', "Smokin' Pandas", 'Laura Hoogland', 'Lowie Trio', 'Zouzibabe', 'Jeroen Delodder', 'Daria Kolosova', 'Lovely Louis', 'DJ Jelle DK', 'Kim Mathijs', 'DC Noises', 'Geheimzinnig Soundsystem', 'DJ Cocki', 'Milinguap', '22heures30']
#
# Final Artist Popularity (703 artists, default popularity of 50 if not found):
# {'DJ Mars': 50, 'Bosart': 0, 'Dietro': 19, 'Voltage': 49, 'Elfigo': 27, '>rthur Lewis ft. Gerben Tuerlinckx': 50, 'Nina Black': 9, 'Michael Amani': 24, 'The Oddword': 9, 'Andromedik': 54, 'Mandy': 65, 'Surprise': 72, 'Unsyn': 26, 'Rayzen': 43, 'K1 & Aradia': 11, 'Hyperverb': 44, 'Footworxx Militant Crew': 18, 'Sakyra': 30, 'HYSTA': 44, 'Vandal': 39, 'Billx': 51, 'Reflexx': 37, 'Unicorn on K': 48, 'Juwlz': 0, 'Maxim Lany': 41, 'Rose Ringed': 33, 'Agents Of Time (Live)': 53, 'Mau P': 54, 'Mathame': 53, 'Don Diablo': 68, 'Hardwell': 69, 'Hawkeyes': 0, 'Yamo': 3, 'Dave
b2b Lens': 0, 'Dimension': 63, 'Bonobo b2b Dixon': 64, 'Milan Evens': 50, 'Cellini': 16, 'Dino Lenny': 37, 'Elkka': 40, 'TSHA': 51, 'Bonobo': 64, 'Dixon': 52, 'Rumix': 55, 'Neall': 25, 'Nico Parisi': 21, 'Anonymize': 7, 'Jens Lissat': 36, 'Franky Jones': 43, 'DJ Ghost': 45, 'Furax': 44, 'Franky Kloeck': 2, 'Push': 73, 'Bonzai All Stars': 16, 'Two/Three': 13, 'YULI ANA': 0, 'MCR-T': 86, 'Parkerstrange': 17, 'Klaudia Gawlas': 29, 'Parfait & Charlie Sparks': 18, 'Callush': 12, 'Yo-ki': 54, 'Kaspa': 45, 'Brits & Boen': 21, 'Los Bomberos': 0, 'Schuurrallures': 50, 'Bobby & Djenko': 0, 'Monta': 62, 'Deuxfwa': 50, 'White Noise': 84, 'Neon': 70, 'Antdot': 61, 'Alex Wann': 62, 'Dom Dolla': 71, 'Solomun b2b Four Tet': 60, 'Kenn Colt': 34, 'Stephine B': 50, 'Kryder': 49, 'PARISI (live)': 48, 'Symphony of Unity': 50, 'Salvatore Ganacci': 55, 'Sebastian Ingrosso & Steve Angello': 0, 'MORTEN': 64, 'REZZMAU5': 29, 'TBA': 22, 'Juul Pence': 50, 'Aline Rocha': 12, 'Melon Bomb': 10, 'Melvo Baptiste': 20, 'Jayda G': 51, 'Jellybean Benitez': 23, 'Alexander Merlin': 35, 'Loulou Players': 30, 'Manuals': 18, 'Cat Dealers': 58, 'Goodboys': 68, 'Sub Focus & ID': 68, 'Sam Oui': 0, 'Lavern': 70,  ...

# %%
 # # Save the dictionary to a CSV file
# with open("doc/artist_popularity.csv", "w", newline="") as file:
#     writer = csv.writer(file)
#     writer.writerow(["Artist", "Popularity"])  # Add a header row
#     for artist, popularity in p_a.items():
#         writer.writerow([artist, popularity])
#
# print("Artist popularity dictionary saved to 'artist_popularity.csv'")
# Out:
# Artist popularity dictionary saved to 'artist_popularity.csv'

# %%
# Read the dictionary from a CSV file
with open("doc/artist_popularity.csv", "r") as file:
    reader = csv.reader(file)
    next(reader)  # Skip the header row
    p_a = {rows[0]: int(rows[1]) for rows in reader}

print("Artist popularity dictionary loaded:")
print(p_a)
# Out:
# Artist popularity dictionary loaded:
# {'DJ Mars': 50, 'Bosart': 0, 'Dietro': 19, 'Voltage': 49, 'Elfigo': 27, '>rthur Lewis ft. Gerben Tuerlinckx': 50, 'Nina Black': 9, 'Michael Amani': 24, 'The Oddword': 9, 'Andromedik': 54, 'Mandy': 65, 'Surprise': 72, 'Unsyn': 26, 'Rayzen': 43, 'K1 & Aradia': 11, 'Hyperverb': 44, 'Footworxx Militant Crew': 18, 'Sakyra': 30, 'HYSTA': 44, 'Vandal': 39, 'Billx': 51, 'Reflexx': 37, 'Unicorn on K': 48, 'Juwlz': 0, 'Maxim Lany': 41, 'Rose Ringed': 33, 'Agents Of Time (Live)': 53, 'Mau P': 54, 'Mathame': 53, 'Don Diablo': 68, 'Hardwell': 69, 'Hawkeyes': 0, 'Yamo': 3, 'Dave Lambert': 6, 'Makasi': 
': 63, 'Bonobo b2b Dixon': 64, 'Milan Evens': 50, 'Cellini': 16, 'Dino Lenny': 37, 'Elkka': 40, 'TSHA': 51, 'Bonobo': 64, 'Dixon': 52, 'Rumix': 55, 'Neall': 25, 'Nico Parisi': 21, 'Anonymize': 7, 'Jens Lissat': 36, 'Franky Jones': 43, 'DJ Ghost': 45, 'Furax': 44, 'Franky Kloeck': 2, 'Push': 73, 'Bonzai All Stars': 16, 'Two/Three': 13, 'YULI ANA': 0, 'MCR-T': 86, 'Parkerstrange': 17, 'Klaudia Gawlas': 29, 'Parfait & Charlie Sparks': 18, 'Callush': 12, 'Yo-ki': 54, 'Kaspa': 45, 'Brits & Boen': 21, 'Los Bomberos': 0, 'Schuurrallures': 50, 'Bobby & Djenko': 0, 'Monta': 62, 'Deuxfwa': 50, 'White Noise': 84, 'Neon': 70, 'Antdot': 61, 'Alex Wann': 62, 'Dom Dolla': 71, 'Solomun b2b Four Tet': 60, 'Kenn Colt': 34, 'Stephine B': 50, 'Kryder': 49, 'PARISI (live)': 48, 'Symphony of Unity': 50, 'Salvatore Ganacci': 55, 'Sebastian Ingrosso & Steve Angello': 0, 'MORTEN': 64, 'REZZMAU5': 29, 'TBA': 22, 'Juul Pence': 50, 'Aline Rocha': 12, 'Melon Bomb': 10, 'Melvo Baptiste': 20, 'Jayda G': 51, 'Jellybean Benitez': 23, 'Alexander Merlin': 35, 'Loulou Players': 30, 'Manuals': 18, 'Cat Dealers': 58, 'Goodboys': 68, 'Sub Focus & ID': 68, 'Sam Oui': 0, 'Lavern': 70,  ...

# %% [markdown]
# ####  <b style="color: #8B0000;">2.2.3 From Both Line-up and Artist Information</b>

# %% [markdown]
# We calculated normalized popularity scores for both days ($p_d$) and stages ($p_ s$) based on the aggregate popularity of artists performing on each day and stage. The normalization rescales the scores to a range of 0 to 100 for consistency and comparability.
#
# Day Popularity Score $p_d$: $ p_d = \sum_{a \in A_{d}} p_a $ with $A_{d}$ the set of artists performing on day $d$.
#
# Stage Popularity Score $p_s$: $ p_s = \sum_{a \in A_{s}} p_a $ with $A_{s}$ the set of artists performing on stage $s$.

# %%
# * Popularity score for days
# Calculate day popularity scores
p_d = lineup_df.groupby('Day_Combined_ID').apply(
    lambda group: group['Artist'].map(p_a).sum()
).to_dict()

# Print day popularity scores
print("\nDay Popularity Scores (p_d):")
print(p_d)

# Normalize day popularity scores
# Avoid division by zero if all values are identical
# Normalize day popularity scores to a range of 0-100
min_pd, max_pd = 0, max(p_d.values())

if max_pd - min_pd == 0:
    p_d_normalized = {day: 100 for day in p_d.keys()}
else:
    p_d_normalized = {
        day: ((score - min_pd) / (max_pd - min_pd)) * 100
        for day, score in p_d.items()
    }

# Print day popularity scores
print("\nNormalized Day Popularity Scores (p_d):")
print(p_d_normalized)

p_d = p_d_normalized
# Out:
# Day Popularity Scores (p_d):
# {1: 5396, 2: 5363, 3: 5411, 4: 5399, 5: 5811, 6: 5429, 7: 644, 8: 516}
#
# Normalized Day Popularity Scores (p_d):
# {1: 92.85837205300292, 2: 92.29048356565134, 3: 93.11650318361728, 4: 92.90999827912579, 5: 100.0, 6: 93.4262605403545, 7: 11.082429874376183, 8: 8.879710893133712}
# C:\Users\LunaG\AppData\Local\Temp\ipykernel_24748\3970254409.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   p_d = lineup_df.groupby('Day_Combined_ID').apply(

# %%
# * Popularity score for stage
# Calculate stage popularity scores
p_s = lineup_df.groupby('Stage Name').apply(
    lambda group: group['Artist'].map(p_a).sum()
).to_dict()

# Print stage popularity scores
print("\nStage Popularity Scores (p_s):")
print(p_s)

# Normalize stage popularity scores
# Avoid division by zero if all values are identical
# Normalize stage popularity scores to a range of 0-100
min_ps, max_ps = 0, max(p_s.values())

if max_ps - min_ps == 0:
    p_s_normalized = {day: 100 for day in p_s.keys()}
else:
    p_s_normalized = {
        day: ((score - min_ps) / (max_ps - min_ps)) * 100
        for day, score in p_s.items()
    }

# Print day popularity scores
print("\nNormalized Stage Popularity Scores (p_s):")
print(p_s_normalized)

p_s = p_s_normalized
# Out:
# Stage Popularity Scores (p_s):
# {'Atmosphere': 2015, 'Cage': 1857, 'Casa Corona': 1504, 'Core': 1647, 'Crystal Garden': 2261, 'Elixir': 1935, 'Freedom': 2102, 'House of Fortune': 2252, 'Library': 4154, 'Mainstage': 3698, 'Moosebar': 746, 'Planaxis': 2165, 'Rave Cave': 1672, 'Rise': 1946, 'Rose Garden': 2855, 'The Gathering': 1160}
#
# Normalized Stage Popularity Scores (p_s):
# {'Atmosphere': 48.507462686567166, 'Cage': 44.703899855560906, 'Casa Corona': 36.20606644198363, 'Core': 39.64853153586904, 'Crystal Garden': 54.429465575349056, 'Elixir': 46.58160808858931, 'Freedom': 50.60182956186809, 'House of Fortune': 54.21280693307655, 'Library': 100.0, 'Mainstage': 89.02262879152623, 'Moosebar': 17.958594126143478, 'Planaxis': 52.118440057775636, 'Rave Cave': 40.25036109773712, 'Rise': 46.846413095811265, 'Rose Garden': 68.72893596533461, 'The Gathering': 27.924891670678864}
# C:\Users\LunaG\AppData\Local\Temp\ipykernel_24748\1942884588.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   p_s = lineup_df.groupby('Stage Name').apply(

# %% [markdown]
# ###  <b style="color: #8B0000;">2.3 Preparing Data Variables for PuLP</b>

# %% [markdown]
# ####  <b style="color: #8B0000;">2.3.1 Sets</b>

# %%
# * Set of Stages S
S = lineup_df['Stage Name'].unique().tolist()
print(f"Stage if of type {type(S[0])}") # Set of strings
print(S)
# Out:
# Stage if of type <class 'str'>
# ['The Gathering', 'Cage', 'Freedom', 'House of Fortune', 'Crystal Garden', 'Library', 'Mainstage', 'Elixir', 'Moosebar', 'Rose Garden', 'Rave Cave', 'Rise', 'Core', 'Planaxis', 'Atmosphere', 'Casa Corona']

# %%
# * Set of Artists
print(f"Artist is of type {type(A[0])}") # Set of strings
print(A)
# Out:
# Artist is of type <class 'str'>
# ['DJ Mars', 'Bosart', 'Dietro', 'Voltage', 'Elfigo', '>rthur Lewis ft. Gerben Tuerlinckx', 'Nina Black', 'Michael Amani', 'The Oddword', 'Andromedik', 'Mandy', 'Surprise', 'Unsyn', 'Rayzen', 'K1 & Aradia', 'Hyperverb', 'Footworxx Militant Crew', 'Sakyra', 'HYSTA', 'Vandal', 'Billx', 'Reflexx', 'Unicorn on K', 'Juwlz', 'Maxim Lany', 'Rose Ringed', 'Agents Of Time (Live)', 'Mau P', 'Mathame', 'Don Diablo', 'Hardwell', 'Hawkeyes', 'Yamo', 'Dave Lambert', 'Makasi', 'DJs From Mars', 'Nicky Romero', 'Seth Hills', 'Chico Rose', 'Henri PFR', 'Kayu', 'Meera', 'Samm & Ajna', 'DBN Gogo', 'Alan Dixon', 'WhoMadeWho', 'Keinemusik (&ME, Adam Port, Rampa)', 'Q DANCE End show', 'Dolores', 'Reygel', 'Whisnu Santika', 'Kris Kross Amsterdam', 'Trinix', 'B Jones', 'Regi & Mark With a K', 'Maddix', 'Nervo', 'Sound Rush', 'Ran-D', 'Daybreak Session: Oliver Heldens', 'Miss Monique', 'Öwnboss', 'W&W', 'Vintage Culture', 'Da Tweekaz', 'John Newman', 'Netsky', 'Kölsch', 'Swedish House Mafia', 'Armin van Buuren', 'Guilini', 'C-Track', 'Jaël Ost & MagiK', 'Rick & James 80’s Party', 'STUK', 'Eagl', 'Jamie Lee Six & Louis XIV', 'Audiowave & MC Rim', 'Kamal Bankay', 'DJ Gerrit', 'Funktastix', 'Gebroeders KO', 'Thierry VonderWarth', 'Blanko & ATMOS', 'Kara', 'Georgie Riot & Captain Bass', 'Tisoki & Oliverse', 'SOTA', 'Vampa', 'Murdock', 'ATLiens', 'Friction', 'USED', 'Wilkinson', 'Const.', 'Nightcrow', 'Kimman', 'Mell Tierra', 'Ben Malone', 'Justin Wilkes', 'Jana Vitiligo', 'Dre Guazzelli', 'DJ Daan', 'Alfred Beck', 'Giuseppe Ottaviani', 'Xijaro & Pitch', 'Ruben de Ronde', 'Nifra', 'Aaron Hibell', 'Cosmic Gate', 'Aly & Fila', 'A Local Hero', 'Piaggio Disco Club', 'Desiree', 'Shanti Celeste', 'DJ Heartstring', 'Bashkka', 'Denis Sulta', 'KEVIN KOFII', 'Novak', 'Philou Louzolo', 'Calussa', 'Hugel', 'Amémé', 'Sunnery James & Ryan Marciano', 'Sunnery James & Ryan Marciano b2b Philou Louzolo b2b Amémé', 'BYØRN', 'Novah', 'LESSSS', 'VIDO', 'Azyr', 'Trym', 'Sara Landry', 'Oguz', 'Dyen', 'Poleen', 'NSI', 'John Bowtie', 'Stasi Sanlin', 'Arado', 'Afshin Momadi', 'Birds Of Mind', 'Ann Clue', 'VTSS', 'DJ Archie', 'Merow', 'Basstripper b2b Primate', 'Harriet Jaxxon', 'MONTELL2099', 'Koven', 'Grafix', 'Kanine', 'Luude', 'Charlie Tee b2b Lens', 'Dimension', 'Bonobo b2b Dixon', 'Milan Evens', 'Cellini', 'Dino Lenny', 'Elkka', 'TSHA', 'Bonobo', 'Dixon', 'Rumix', 'Neall', 'Nico Parisi', 'Anonymize', 'Jens Lissat', 'Franky Jones', 'DJ Ghost', 'Furax', 'Franky Kloeck', 'Push', 'Bonzai All Stars', 'Two/Three', 'YULI ANA', 'MCR-T', 'Parkerstrange', 'Klaudia Gawlas', 'Parfait & Charlie Sparks', 'Callush', 'Yo-ki', 'Kaspa', 'Brits & Boen', 'Los Bomberos', 'Schuurrallures', 'Bobby & Djenko', 'Monta', 'Deuxfwa', 'White Noise', 'Neon', 'Antdot', 'Alex Wann', 'Dom Dolla', 'Solomun b2b Four Tet', 'Kenn Colt', 'Stephine B', 'Kryder', 'PARISI (live)', 'Symphony of Unity', 'Salvatore Ganacci', 'Sebastian Ingrosso & Steve Angello', 'MORTEN', 'REZZMAU5', 'TBA', 'Juul Pence', 'Aline Rocha', 'Melon Bomb', 'Melvo Baptiste', 'Jayda G', 'Jellybean Benitez', 'Alexander Merlin', 'Loulou Players', 'Manuals', 'Cat Dealers', 'Goodboys', 'Sub Focus & ID', 'Sam Oui', 'Lavern', 'Pretty Pink', 'Marten Hørger', 'Azteck', 'Odd Mob', 'Gryffin', 'Acraze', 'Kungs', 'Lost Frequencies', 'Claptone', 'Daybreak Session: Laidback Luke presents Wayback Luke', 'Eliza Rose', 'Yves V', 'MANDY', 'Amelie Lens', 'Alok', 'Anyma', 'Dimitri Vegas & Like Mike', 'Timmy Trumpet', 'Naomi Cazier', 'DJ Señor Funk', 'Nothing But Funk', 'Moska', 'Yero', 'Lou8', 'Ewave', 'Raphi', 'Funkhauser', 'Jerrooo', 'Milano', 'Natalia', 'Nick Bril', 'Collé', 'Capoon', 'Mahmut Orhan', 'Brina Knauss', 'Fideles', 'Mind Against', 'Tobi Trekhaak', 'Hollaback Soundystem', 'DOEMP', 'Mariah Curry', 'Olsan Twins', 'Discobaar A Moeder', 'Gomorris', 'Kiësto', 'X-TOF', 'Bingo Players', 'Jay Hardway', 'Moguai', 'Dannic', 'Chuckie', 'Blasterjaxx', 'DVBBS', 'Axel Haube', 'Olympe', 'Kasia', 'Chris Avantgarde', 'Kevin de Vries', 'MRAK', 'Tale Of Us', 're-type', 'Be ...

# %%
# * Set of Sets of an Artist
K_a = lineup_df.groupby('Artist')['Set_ID'].apply(list).to_dict()
# Print type information for the first row only
artist, sets = next(iter(K_a.items()))
print(f"Key (Artist) is of type {type(artist)}") # String
print(f"Value (Set of Set_IDs) is of type {type(sets)}") # List
print(f"Part of Value (Set_ID) is of type {type((sets[0]))}") # Int

print(K_a)
# Out:
# Key (Artist) is of type <class 'str'>
# Value (Set of Set_IDs) is of type <class 'list'>
# Part of Value (Set_ID) is of type <class 'int'>
# {'22heures30': [1], '3 Are Legend': [1], '5napback': [1, 2], '8Kays': [1], '999999999': [1], '>rthur Lewis ft. Gerben Tuerlinckx': [1], 'A Little Sound': [1], 'A Local Hero': [1], 'A-trak b2b The Magician': [1], 'ANNA': [1, 2], 'ARKADYAN': [1], 'ARTEN': [1], 'ATLiens': [1], 'Aaron Hibell': [1], 'Abena': [1], 'Acraze': [1], 'Adam Beyer': [1], 'Adam Sellouk': [1], 'AdamK': [1], 'Admess': [1], 'Adriatique': [1, 2], 'Afrojack
DJ Fasta': [1], 'DJ Furax': [1], 'DJ Gerrit': [1], 'DJ Ghost': [1, 2], 'DJ Heartstring': [1, 2], 'DJ Hyperdrive': [1], 'DJ Isaac': [1], 'DJ Jan': [1], 'DJ Jelle DK': [1], 'DJ Kat': [1], 'DJ Licious': [1], 'DJ Luk': [1], 'DJ Mars': [1], 'DJ Robin': [1], 'DJ Roop': [1], 'DJ Sahra': [1], 'DJ Señor Funk': [1], 'DJs From Mars': [1], 'DOEMP': [1], 'DRS b2b Sandy Warez': [1], 'DVBBS': [1, 2], 'Da Tweekaz': [1, 2], 'Dan Shake': [1], 'Dana Montana': [1], 'Dannic': [1], 'Danny Howard': [1], 'Daria Kolosova': [1], 'Dave Lambert': [1], 'David Guetta': [1], 'Daybreak Session: Antdot b2b Maz': [1], 'Daybreak Session: Laidback Luke presents Wayback Luke': [1], 'Daybreak Session: Oliver Heldens': [1], 'Daybreak Session: One World Radio Soundsystem': [1, 2], 'Daybreak session: Laidback Luke presents Wayback Luke': [1], 'Delafino & DJ Licious': [1], 'Delafino & Ibiza Friends': [1], 'Delafino B2B DJ Gee': [1], 'Delafino b2b Luna Fino': [1], 'Delta Heavy': [1], 'Denis Sulta': [1], 'Dennis Cruz b2b Seth Troxler': [1], 'Desiree': [1], 'Detest': [1], 'Deuxfwa': [1], 'Diego Miranda': [1], 'Dietro': [1], 'Dieux Pere': [1], 'Dimension': [1, 2], 'Dimitri Vegas & Like Mike': [1, 2, 3], 'Dimitri Vegas & Like Mike & Friends': [1], 'Di ...

# %%
# * Set of Days D
D = lineup_df['Day_Combined_ID'].unique().tolist()
print(f"Day is of type {type(D[0])}") #Int
print(D)

for d in D:
    rows = lineup_df[lineup_df['Day_Combined_ID'] == d]
    # Correctly select the specified columns
    print(rows[['Day_Combined_ID', 'Day', 'Weekend']].iloc[0])
# Out:
# Day is of type <class 'int'>
# [7, 1, 3, 5, 8, 2, 4, 6]
# Day_Combined_ID            7
# Day                 Thursday
# Weekend            Weekend 1
# Name: 0, dtype: object
# Day_Combined_ID            1
# Day                   Friday
# Weekend            Weekend 1
# Name: 15, dtype: object
# Day_Combined_ID            3
# Day                 Saturday
# Weekend            Weekend 1
# Name: 149, dtype: object
# Day_Combined_ID            5
# Day                   Sunday
# Weekend            Weekend 1
# Name: 276, dtype: object
# Day_Combined_ID            8
# Day                 Thursday
# Weekend            Weekend 2
# Name: 408, dtype: object
# Day_Combined_ID            2
# Day                   Friday
# Weekend            Weekend 2
# Name: 422, dtype: object
# Day_Combined_ID            4
# Day                 Saturday
# Weekend            Weekend 2
# Name: 561, dtype: object
# Day_Combined_ID            6
# Day                   Sunday
# Weekend            Weekend 2
# Name: 698, dtype: object

# %%
# * Set of Starting Times
# Set of Starting Times
time_slot_granularity = 5  # Change this value as needed
T_ds = {}

for _, row in stage_availability.iterrows():
    stage = row['Stage Name']
    day = row['Day_Combined_ID']

    # Use Start Time and End Time directly (already datetime objects)
    start_time = row['Start Time']
    end_time = row['End Time']

    # Generate time slots
    time_slots = pd.date_range(
        start=start_time,
        end=end_time,
        freq=f'{time_slot_granularity}min'
    ).tolist()

    # Assign to T_ds with (stage, day) tuple key
    T_ds[(stage, day)] = time_slots

# Print type information for the first row only
key, value = next(iter(T_ds.items()))
print(f"Key (Stage, Day) is of type {type(key)}; e.g. {key}") # Tuple
print(f"Part of Key (Stage) is of type {type(key[0])}; e.g. {key[0]}") #String
print(f"Part of Key (Day) is of type {type(key[1])}; e.g. {key[1]}") # Int
print(f"Value (Time Slots) is of type {type(value)}; e.g. {value}") # List
print(f"Part of Value (Time Slot) is of type {type(value[0])}; e.g. {value[0]}") # Timestamp

# Print the resulting T_ds
print("T_ds:")
print(T_ds)
# Out:
# Key (Stage, Day) is of type <class 'tuple'>; e.g. ('Atmosphere', 1)
# Part of Key (Stage) is of type <class 'str'>; e.g. Atmosphere
# Part of Key (Day) is of type <class 'int'>; e.g. 1
# Value (Time Slots) is of type <class 'list'>; e.g. [Timestamp('2024-07-19 12:00:00'), Timestamp('2024-07-19 12:05:00'), Timestamp('2024-07-19 12:10:00'), Timestamp('2024-07-19 12:15:00'), Timestamp('2024-07-19 12:20:00'), Timestamp('2024-07-19 12:25:00'), Timestamp('2024-07-19 12:30:00'), Timestamp('2024-07-19 12:35:00'), Timestamp('2024-07-19 12:40:00'), Timestamp('2024-07-19 12:45:00'), Timestamp('2024-07-19 12:50:00'), Timestamp('2024-07-19 12:55:00'), Timestamp('2024-07-19 13:00:00'), Timestamp('2024-07-19 13:05:00'), Timestamp('2024-07-19 13:10:00'), Timestamp('2024-07-19 13:15:00'), Timestamp('2024-07-19 13:20:00'), Timestamp('2024-07-19 13:25:00'), Timestamp('2024-07-19 13:30:00'), Timestamp('2024-07-19 13:35:00'), Timestamp('2024-07-19 13:40:00'), Timestamp('2024-07-19 13:45:00'), Timestamp('2024-07-19 13:50:00'), Timestamp('2024-07-19 13:55:00'), Timestamp('2024-07-19 14:00:00'), Timestamp('2024-07-19 14:05:00'), Timestamp('2024-07-19 14:10:00'), Timestamp('2024-07-19 14:15:00'), Timestamp('2024-07-19 14:20:00'), Timestamp('2024-07-19 14:25:00'), Timestamp('2024-07-19 14:30:00'), Timestamp('2024-07-19 14:35:00'), Timestamp('2024-07-19 14:40:00'), Timestamp('2024-07-19 14:45:00'), Timestamp('2024-07-19 14:50:00'), Timestamp('2024-07-19 14:55:00'), Timestamp('2024-07-19 15:00:00'), Timestamp('2024-07-19 15:05:00'), Timestamp('2024-07-19 15:10:00'), Timestamp('2024-07-19 15:15:00'), Timestamp('2024-07-19 15:20:00'), Timestamp('2024-07-19 15:25:00'), Timestamp('2024-07-19 15:30:00'), Timestamp('2024-07-19 15:35:00'), Timestamp('2024-07-19 15:40:00'), Timestamp('2024-07-19 15:45:00'), Timestamp('2024-07-19 15:50:00'), Timestamp('2024-07-19 15:55:00'), Timestamp('2024-07-19 16:00:00'), Timestamp('2024-07-19 16:05:00'), Timestamp('2024-07-19 16:10:00'), Timestamp('2024-07-19 16:15:00'), Timestamp('2024-07-19 16:20:00
timestamp('2024-07-19 19:10:00'), Timestamp('2024-07-19 19:15:00'), Timestamp('2024-07-19 19:20:00'), Timestamp('2024-07-19 19:25:00'), Timestamp('2024-07-19 19:30:00'), Timestamp('2024-07-19 19:35:00'), Timestamp('2024-07-19 19:40:00'), Timestamp('2024-07-19 19:45:00'), Timestamp('2024-07-19 19:50:00'), Timestamp('2024-07-19 19:55:00'), Timestamp('2024-07-19 20:00:00'), Timestamp('2024-07-19 20:05:00'), Timestamp('2024-07-19 20:10:00'), Timestamp('2024-07-19 20:15:00'), Timestamp('2024-07-19 20:20:00'), Timestamp('2024-07-19 20:25:00'), Timestamp('2024-07-19 20:30:00'), Timestamp('2024-07-19 20:35:00'), Timestamp('2024-07-19 20:40:00'), Timestamp('2024-07-19 20:45:00'), Timestamp('2024-07-19 20:50:00'), Timestamp('2024-07-19 20:55:00'), Timestamp('2024-07-19 21:00:00'), Timestamp('2024-07-19 21:05:00'), Timestamp('2024-07-19 21:10:00'), Timestamp('2024-07-19 21:15:00'), Timestamp('2024-07-19 21:20:00'), Timestamp('2024-07-19 21:25:00'), Timestamp('2024-07-19 21:30:00'), Timestamp('2024-07-19 21:35:00'), Timestamp('2024-07-19 21:40:00'), T ...

# %%
# For Pulp, we can onlu use real number and no timestamps.... lets look at a solution here
def to_minutes_since_midnight(timestamp, d):
    # Get total minutes since midnight
    minutes = timestamp.hour * 60 + timestamp.minute
    # Add 1440 minutes (24 hours) for times past midnight
    rows = lineup_df[lineup_df['Day_Combined_ID'] == d].iloc[0]
    day = rows['Start Time'].day
    if timestamp.day > day:  # Adjust "18" based on the logical festival day
        minutes += 1440
    return minutes

# %%
T_ds = {
    key: [to_minutes_since_midnight(slot, key[1]) for slot in slots]
    for key, slots in T_ds.items()
}
# Print the resulting T_ds
print("T_ds:")
print(T_ds)
# Out:
# T_ds:
# {('Atmosphere', 1): [720, 725, 730, 735, 740, 745, 750, 755, 760, 765, 770, 775, 780, 785, 790, 795, 800, 805, 810, 815, 820, 825, 830, 835, 840, 845, 850, 855, 860, 865, 870, 875, 880, 885, 890, 895, 900, 905, 910, 915, 920, 925, 930, 935, 940, 945, 950, 955, 960, 965, 970, 975, 980, 985, 990, 995, 1000, 1005, 1010, 1015, 1020, 1025, 1030, 1035, 1040, 1045, 1050, 1055, 1060, 1065, 1070, 1075, 1080, 1085, 1090, 1095, 1100, 1105, 1110, 1115, 1120, 1125, 1130, 1135, 1140, 1145, 1150, 1155, 1160, 1165, 1170, 1175, 1180, 1185, 1190, 1195, 1200, 1205, 1210, 1215, 1220, 1225, 1230, 1235, 1240, 1245, 1250, 1255, 1260, 1265, 1270, 1275, 1280, 1285, 1290, 1295, 1300, 1305, 1310, 1315, 1320, 1325, 1330, 1335, 1340, 1345, 1350, 1355, 1360, 1365, 1370, 1375, 1380, 1385, 1390, 1395, 1400, 1405, 1410, 1415, 1420, 1425, 1430, 1435, 1440, 1445, 1450, 1455, 1460, 1465, 1470, 1475, 1480, 1485, 1490, 1495], ('Atmosphere', 2): [720, 
K': [1], 'Admess': [1], 'Adriatique': [1, 2], 'Afrojack': [1, 2], 'Afshin Momadi': [1], 'Agents Of Time': [1], 'Agents Of Time (Live)': [1], 'Airglo': [1], 'Alan Dixon': [1], 'Alesso': [1, 2], 'Alex Wann': [1], 'Alexander Merlin': [1], 'Alexander Popov b2b Re-Twin': [1], 'Alfred Beck': [1], 'Alibi': [1], 'Aline Rocha': [1], 'Alok': [1, 2], 'Aly & Fila': [1], 'Amber Broos': [1, 2], 'Amelie Lens': [1, 2], 'Amotik b2b Answer Code Request': [1], 'Amémé': [1], 'Andrei Stan': [1], 'Andromedik': [1, 2, 3], 'Angemi': [1], 'Ann Clue': [1], 'Annabel Stop It': [1], 'Anonymize': [1], 'Antdot': [1], 'Anyma': [1, 2], 'Arado': [1, 2], 'Argy': [1], 'Arielle Free': [1], 'Armin van Buuren': [1, 2], 'Ashibah': [1], 'Assia MK': [1], 'Astrality': [1], 'Audiowave & MC Rim': [1], 'Avalon': [1], 'Avangart Tabldot': [1], 'Aversion': [1], 'Axel Haube': [1, 2], 'Azo': [1], 'Azteck': [1], 'Azyr': [1], 'B Jones': [1, 2], 'BAVR': [1], 'BKAY': [1], 'BYØRN': [1], 'Ballantine': [1], 'Bardy b2b OCSAV': [1], 'Barry Fest': [1], 'Bart Skils': [1], 'Bashkka': [1], 'BassBrain': [1], 'Bassbar': [1], 'Bassjackers': [1, 2, 3], 'Basstripper b2b AC13': [1], 'Basstripper b2b Primate': [1], 'Ben Malone': [1], 'Benny': [1], 'Bensley': [1], 'Bermio': [1], 'Bhaskar': [1], 'Bibi Seck': [1], 'Billx': [1], 'Bingo Players': [1], 'Birds Of Mind': [1], 'Blanko & ATMOS': [1], 'Blanko & Marge': [1], 'Blasterjaxx': [1, 2], 'Blazy': [1], 'Blk.': [1], 'Block & Crown': [1], 'Bobby & Djenko': [1], 'Bonobo': [1], 'Bonobo b2b Dixon': [1], 'Bonzai All Stars': [1, 2], 'Bora Uzer': [1], 'Boris Brejcha': [1], 'Bosart': [1], 'Boycot': [1], 'Bram Delux': [1], 'Bredren': [1], 'Brennan Heart': [1], 'Bresh': [1], 'Brian': [1], 'Brian Cross & DJ Nano': [1], 'Brina Knauss': [1], 'Brits & Boen': [1], 'C-Track': [1], 'Calao': [1], 'Callush': [1], 'Calussa': [1], 'Camo & Krooked': [1], 'Capoon': [1], 'Cassian': [1], 'Cat Dealers': [1, 2], 'Cellini': [1], 'Chapter & Verse': [1], 'Charlie Tee b2b Lens': [1], 'Chico Rose': [1], 'Chris Avantgarde': [1, 2], 'Chris Stussy': [1], 'Christophe b2b Seelen': [1], 'Chuckie': [1, 2], 'Chyl': [1], 'Claptone': [1, 2], 'Collé': [1], 'Const.': [1], 'Coone': [1], 'Cosmic Gate': [1], 'Cristiano Da Silva': [1], 'D. Guaetta': [1], 'DBN Gogo': [1], 'DC Noises': [1], 'DJ Archie': [1], 'DJ Boring': [1], 'DJ Chanelle': [1], 'DJ Cocki': [1], 'DJ Creator': [1], 'DJ Daan': [1], 'DJ Diesel': [1], 'DJ F.R.A.N.K': [1], 'DJ Fasta': [1], 'DJ Furax': [1], 'DJ Gerrit': [1], 'DJ Ghost': [1, 2], 'DJ Heartstring': [1, 2], 'DJ Hyperdrive': [1], 'DJ Isaac': [1], 'DJ Jan': [1], 'DJ Jelle DK': [1], 'DJ Kat': [1], 'DJ Licious': [1], 'DJ Luk': [1], 'DJ Mars': [1], 'DJ Robin': [1], 'DJ Roop': [1], 'DJ Sahra': [1], 'DJ Señor Funk': [1], 'DJs From Mars': [1], 'DOEMP': [1], 'DRS b2b Sandy Warez': [1], 'DVBBS': [1, 2], 'Da Tweekaz': [1, 2], 'Dan Shake': [1], 'Dana Montana': [1], 'Dannic': [1], 'Danny Howard': [1], 'Daria Kolosova': [1], 'Dave Lambert': [1], 'David Guetta': [1], 'Daybreak Session: Antdot b2b Maz': [1], 'Daybreak Session: Laidback Luke presents Wayback Luke': [1], 'Daybreak Session: Oliver Heldens': [1], 'Daybreak Session: One World Radio Soundsystem': [1, 2], 'Daybreak session: Laidback Luke presents Wayback Luke': [1], 'Delafino & DJ Licious': [1], 'Delafino & Ibiza Friends': [1], 'Delafino B2B DJ Gee': [1], 'Delafino b2b Luna Fino': [1], 'Delta Heavy': [1], 'Denis Sulta': [1], 'Dennis Cruz b2b Seth Troxler': [1], 'Desiree': [1], 'Detest': [1], 'Deuxfwa': [1], 'Diego Miranda': [1], 'Dietro': [1], 'Dieux Pere': [1], 'Dimension': [1, 2], 'Dimitri Vegas & Like Mike': [1, 2, 3], 'Dimitri Vegas & Like Mike & Friends': [1], 'Di ...

# %%
# * ek Duration of set k of artist a
# Nested dictionary for Duration of set (e_k)
e_k = lineup_df.groupby('Artist').apply(
    lambda group: group.set_index('Set_ID')['Duration (minutes)'].to_dict()
).to_dict()
print("Parameter (e_k): Duration of each set in minutes (artist-specific)")
print(e_k)
# Out:
# Parameter (e_k): Duration of each set in minutes (artist-specific)
# {'22heures30': {1: 60.0}, '3 Are Legend': {1: 60.0}, '5napback': {1: 45.0, 2: 60.0}, '8Kays': {1: 90.0}, '999999999': {1: 85.0}, '>rthur Lewis ft. Gerben Tuerlinckx': {1: 45.0}, 'A Little Sound': {1: 60.0}, 'A Local Hero': {1: 120.0}, 'A-trak b2b The Magician': {1: 60.0}, 'ANNA': {1: 60.0, 2: 120.0}, 'ARKADYAN': {1: 90.0}, 'ARTEN': {1: 60.0}, 'ATLiens': {1: 60.0}, 'Aaron Hibell': {1: 90.0}, 'Abena': {1: 60.0}, 'Acraze': {1: 60.0}, 'Adam Beyer': {1: 115.0}, 'Adam Sellouk': {1: 90.0}, 'AdamK': {1: 60.0}, 'Admess': {1: 30.0}, 'Adriatique': {1: 60.0, 2: 120.0}, 'Afrojack': {1: 60.0, 2: 60.0}, 'Afshin Momadi': {1: 90.0}, 'Agents Of Time': {1: 60.0}, 'Agents Of Time (Live)': {1: 90.0}, 'Airglo': {1: 60.0}, 'Alan Dixon': {1: 90.0}, 'Alesso': {1: 60.0, 2: 60.0}, 'Alex Wann': {1: 90.0}, 'Alexander Merlin': {1: 60.0}, 'Alexander Popov b2b Re-Twin': {1: 90.0}, 'Alfred Beck': {1: 60.0}, 'Alibi': {1: 60.0}, 'Aline Rocha': {1: 90.0}, 'Alok': {1: 60.0, 2: 60.0}, 'Aly & Fila': {1: 90.0}, 'Amber Broos': {1: 120.0, 2: 60.0}, 'Amelie Lens': {1: 60.0, 2: 120.0}, 'Amotik b2b Answer Code Request': {1: 150.0}, 'Amémé': {1: 90.0}, 'Andrei Stan': {1: 60.0}, 'Andromedik': {1: 30.0, 2: 60.0, 3: 60.0}, 'Angemi': {1: 60.0}, 'Ann Clue': {1: 90.0}, 'Annabel Stop It': {1: 60.0}, 'Anonymize': {1: 90.0}, 'Antdot': {1: 120.0}, 'Anyma': {1: 60.0, 2: 90.0}, 'Arado': {1: 90.0, 2: 120.0}, 'Argy': {1: 90.0}, 'Arielle Free': {1: 90.0}, 'Armin van Buuren': {1: 60.0, 2: 60.0}, 'Ashibah': {1: 90.0}, 'Assia MK': {1: 60.0}, 'Astrality': {1: 90.0}, 'Audiowave & MC Rim': {1: 90.0}, 'Avalon': {1: 90.0}, 'Avangart Tabldot': {1: 180.0}, 'Aversion': {1: 60.0}, 'Axel Haube': {1: 120.0, 2: 90.0}, 'Azo': {1: 90.0}, 'Azteck': {1: 60.0}, 'Azyr': {1: 90.0}, 'B Jones': {1: 60.0, 2: 60.0}, 'BAVR': {1: 90.0}, 'BKAY': {1: 60.0}, 'BYØRN': {1: 90.0}, 'Ballantine': {1: 60.0}, 'Bardy b2b OCSAV': {1: 60.0}, 'Barry Fest': {1: 60.0}, 'Bart Skils': {1: 90.0}, 'Bashkka': {1: 120.0}, 'BassBrain': {1: 60.0}, 'Bassbar': {1: 90.0}, 'Bassjackers': {1: 60.0, 2: 60.0, 3: 60.0}, 'Basstripper b2b AC13': {1: 60.0}, 'Basstripper b2b Primate': {1: 60.0}, 'Ben Malone': {1: 90.0}, 'Benny': {1: 90.0}, 'Bensley': {1: 60.0}, 'Bermio': {1: 60.0}, 'Bhaskar': {1: 60.0}, 'Bibi Seck': {1: 90.0}, 'Billx': {1: 60.0}, 'Bingo Players': {1: 60.0}, 'Birds Of Mind': {1: 90.0}, 'Blanko & ATMOS': {1: 60.0}, 'Blanko & Marge': {1: 60.0}, 'Blasterjaxx': {1: 60.0, 2: 60.0}, 'Blazy': {1: 90.0}, 'Blk.': {1: 55.0}, 'Block & Crown': {1: 60.0}, 'Bobby & Djenko': {1: 90.0}, 'Bonobo': {1: 60.0}, 'Bonobo b2b Dixon': {1: 60.0}, 'Bonzai All Stars': {1: 90.0, 2: 90.0}, 'Bora Uzer': {1: 90.0}, 'Boris Brejcha': {1: 60.0}, 'Bosart': {1: 45.0}, 'Boycot': {1: 60.0}, 'Bram Delux': {1: 60.0}, 'Bredren': {1: 60.0}, 'Brennan Heart': {1: 60.0}, 'Bresh': {1: 60.0}, 'Brian': {1: 60.0}, 'Brian Cross & DJ Nano': {1: 60.0}, 'Brina Knauss': {1: 90.0}, 'Brits & Boen': {1: 60.0}, 'C-Track': {1: 90.0}, 'Calao': {1: 90.0}, 'Callush': {1: 90.0}, 'Calussa': {1: 90.0}, 'Camo & Krooked': {1: 60.0}, 'Capoon': {1: 90.0}, 'Cassian': {1: 90.0}, 'Cat Dealers': {1: 60.0, 2: 60.0}, 'Cellini': {1: 90.0}, 'Chapter & Verse': {1: 40.0}, 'Charlie Tee b2b Lens': {1: 60.0}, 'Chico Rose': {1: 60.0}, 'Chris Avantgarde': {1: 90.0, 2: 90.0}, 'Chris Stussy': {1: 90.0}, 'Christophe b2b Seelen': {1: 60.0}, 'Chuckie': {1: 60.0, 2: 60.0}, 'Chyl': {1: 60.0}, 'Claptone': {1: 60.0, 2: 90.0}, 'Collé': {1: 120.0}, 'Const.': {1: 120.0}, 'Coone': {1: 60.0}, 'Cosmic Gate': {1: 90.0}, 'Cristiano Da Silva': {1: 120.0}, 'D. Guaetta': {1: 60.0}, 'DBN Gogo': {1: 90.0}, 'DC Noises': {1: 120.0}, 'DJ Archie': {1: 60.0}, 'DJ Boring': {1: 120.0}, 'DJ Chanelle': {1: 90.0}, 'DJ Cocki': {1: 60.0}, 'DJ Creator': {1: 60.0}, 'DJ Daan': {1: 90.0}, 'DJ Diesel': {1: 60.0}, 'DJ F.R.A.N.K': {1: 60.0}, 'DJ Fasta': {1: 60.0}, 'DJ Furax': {1: 60.0}, 'DJ Gerrit': {1: 60.0}, 'DJ Ghost': {1: 60.0, 2: 60.0}, 'DJ Heartstring': {1: 120.0, 2: 120.0}, 'DJ Hyperdrive': {1: 90.0}, 'DJ Isaac': {1: 60.0}, 'DJ Jan': {1: 90.0}, 'DJ  ...
# C:\Users\LunaG\AppData\Local\Temp\ipykernel_24748\4127208405.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   e_k = lineup_df.groupby('Artist').apply(

# %% [markdown]
# ####  <b style="color: #8B0000;">2.3.3 Stage-specific parameters</b>

# %%
# * t open s, d
# Update t_open to use string days
t_open = {
    (row['Stage Name'], row['Day_Combined_ID']): row['Start Time']
    for _, row in stage_availability.iterrows()
}

# Print results
print("\n Parameter t_open_sd: Opening time of each stage on each day")
print(t_open)
# Out:
#  Parameter t_open_sd: Opening time of each stage on each day
# {('Atmosphere', 1): Timestamp('2024-07-19 12:00:00'), ('Atmosphere', 2): Timestamp('2024-07-26 12:00:00'), ('Atmosphere', 3): Timestamp('2024-07-20 00:00:00'), ('Atmosphere', 4): Timestamp('2024-07-27 00:00:00'), ('Atmosphere', 5): Timestamp('2024-07-21 12:00:00'), ('Atmosphere', 6): Timestamp('2024-07-28 12:00:00'), ('Cage', 1): Timestamp('2024-07-19 12:00:00'), ('Cage', 2): Timestamp('2024-07-26 12:00:00'), ('Cage', 3): Timestamp('2024-07-20 12:00:00'), ('Cage', 4): Timestamp('2024-07-27 12:00:00'), ('Cage', 5): Timestamp('2024-07-21 13:00:00'), ('Cage', 6): Timestamp('2024-07-28 13:00:00'), ('Casa Corona', 1): Timestamp('2024-07-19 12:00:00'), ('Casa Corona', 2): Timest
00:00'), ('Moosebar', 5): Timestamp('2024-07-21 12:00:00'), ('Moosebar', 6): Timestamp('2024-07-28 12:00:00'), ('Planaxis', 1): Timestamp('2024-07-19 12:00:00'), ('Planaxis', 2): Timestamp('2024-07-26 12:00:00'), ('Planaxis', 3): Timestamp('2024-07-20 12:00:00'), ('Planaxis', 4): Timestamp('2024-07-27 13:00:00'), ('Planaxis', 5): Timestamp('2024-07-21 13:00:00'), ('Planaxis', 6): Timestamp('2024-07-28 13:00:00'), ('Rave Cave', 1): Timestamp('2024-07-19 13:00:00'), ('Rave Cave', 2): Timestamp('2024-07-26 13:00:00'), ('Rave Cave', 3): Timestamp('2024-07-20 13:00:00'), ('Rave Cave', 4): Timestamp('2024-07-27 12:00:00'), ('Rave Cave', 5): Timestamp('2024-07-21 13:00:00'), ('Rave Cave', 6): T ...

# %%
# Convert to minutes, since pulp doesnt work with timestamps
t_open = {key: to_minutes_since_midnight(value, key[1]) for key, value in t_open.items()}
# Print the resulting T_ds
print("t_open:")
print(t_open)
# Out:
# t_open:
# {('Atmosphere', 1): 720, ('Atmosphere', 2): 720, ('Atmosphere', 3): 0, ('Atmosphere', 4): 0, ('Atmosphere', 5): 720, ('Atmosphere', 6): 720, ('Cage', 1): 720, ('Cage', 2): 720, ('Cage', 3): 720, ('Cage', 4): 720, ('Cage', 5): 780, ('Cage', 6): 780, ('Casa Corona', 1): 720, ('Casa Corona', 2): 720, ('Casa Corona', 3): 720, ('Casa Corona', 4): 720, ('Casa Corona', 5): 750, ('Casa Corona', 6): 720, ('Core', 1): 750, ('Core', 2): 720, ('Core', 3): 0, ('Core', 4): 750, ('Core', 5): 780, ('Core', 6): 750, ('Crystal Garden', 1): 720, ('Crystal Garden', 2): 720, ('Crystal Garden', 3): 720, ('Crystal Garden', 4): 720, ('Crystal Garden', 5): 720, ('Crystal Garden', 6): 720, ('Elixir', 1): 780, ('Elixir', 2): 0, ('Elixir', 3): 780, ('Elixir', 4): 0, ('Elixir', 5): 780, ('Elixir', 6): 780, ('Freedom', 1): 720, ('Freedom', 2): 720, ('Freedom', 3): 720, ('Freedom', 4): 720, ('Freedom', 5): 720, ('Freedom', 6): 720, ('House of Fortune', 1): 780, ('House of Fortune', 2): 780, ('House of Fortune', 3): 780, ('House of Fortune', 4): 780, ('House of Fortune', 5): 780, ('House of Fortune', 6): 780, ('Library', 1): 35, ('Library', 2): 35, ('Library', 3): 0, ('Library', 4): 0, ('Library', 5): 720, ('Library', 6): 720, ('Mainstage', 1): 720, ('Mainstage', 2): 720, ('Mainstage', 3): 720, ('Mainstage', 4): 720, ('Mainstage', 5): 720, ('Mainstage', 6): 720, ('Moosebar', 1): 720, ('Moosebar', 2): 720, ('Moosebar', 3): 720, ('Moosebar', 4): 720, ('Moosebar', 5): 720, ('Moosebar', 6): 720, ('Planaxis', 1): 720, ('Planaxis', 2): 720, ('Planaxis', 3): 720, ('Planaxis', 4): 780, ('Planaxis', 5): 780, ('Planaxis', 6): 780, ('Rave Cave', 1): 780, ('Rave Cave', 2): 780, ('Rave Cave', 3): 780, ('Rave Cave', 4): 720, ('Rave Cave', 5): 780, ('Rave Cave', 6): 720, ('Rise', 1): 750, ('Rise', 2): 750, ('Rise', 3): 750, ('Rise', 4): 720, ('Rise', 5): 750, ('Rise', 6): 750, ('Rose Garden', 1): 780, ('Rose Garden', 2): 720, ('Rose Garden', 3): 780, ('Rose Garden', 4): 780, ('Rose Garden', 5): 780, ('Rose Garden', 6): 780, ('The Gathering', 7): 810, ('The Gathering', 8): 810}

# %%
# * t close s, d
# Create t_close as a flat dictionary
t_close = {
    (row['Stage Name'], row['Day_Combined_ID']): row['End Time']
    for _, row in stage_availability.iterrows()
}

# Print results
print("\n Parameter t_close_sd: Closing time of each stage on each day")
print(t_close)
# Out:
#  Parameter t_close_sd: Closing time of each stage on each day
# {('Atmosphere', 1): Timestamp('2024-07-20 00:55:00'), ('Atmosphere', 2): Timestamp('2024-07-27 00:55:00'), ('Atmosphere', 3): Timestamp('2024-07-21 00:00:00'), ('Atmosphere', 4): Timestamp('2024-07-28 00:00:00'), ('Atmosphere', 5): Timestamp('2024-07-21 23:55:00'), ('Atmosphere', 6): Timestamp('2024-07-28 23:55:00'), ('Cage', 1): Timestamp('2024-07-19 23:00:00'), ('Cage', 2): Timestamp('2024-07-26 23:00:00'), ('Cage', 3): Timestamp('2024-07-20 23:00:00'), ('Cage', 4): Timestamp('2024-07-27 23:00:00'), ('Cage', 5): Timestamp('2024-07-21 23:00:00'), ('Cage', 6): Timestamp('2024-07-28 23:00:00'), ('Casa Corona', 1): Timestamp('2024-07-20 00:00:00'), ('Casa Corona', 2): Timestamp('2024-07-27 00:00:00'), ('Casa Corona', 3): Timestamp('2024-07-21 00:00:00'), ('Casa Corona', 4): Timestamp('2024-07-28 00:00:00'), ('Casa Corona', 5): Timestamp('2024-07-21 23:00:00'), ('Casa Corona', 6): Timestamp('2024-07-28 23:00:00'), ('Core', 1): Timestamp('2024-07-20 01:00:00'), ('Core', 2): Timestamp('2024-07-27 01:00:00'), ('Core', 3): Timestamp('2024-07-21 00:00:00'), ('Core', 4): Timestamp('2024-07-28 01:00:00'), ('Core', 5): Timestamp('2024-07-22 00:00:00'), ('Core', 6): Timestamp('2024-07-29 00:00:00'), ('Crystal Garden', 1): Timestamp('2024-07-20 00:30:00'), ('Crystal Garden', 2): Timestamp('2024-07-27 00:30:00'), ('Crystal Garden', 3): Timestamp('2024-07-21 00:30:00'), ('Crystal Garden', 4): Timestamp('2024-07-28 00:30:00'), ('Crystal Garden', 5): Timestamp('2024-07-21 23:30:00'), ('Crystal Garden', 6): Timestamp('2024-07-28 23:30:00'), ('Elixir', 1): Timestamp('2024-07-20 01:00:00'), ('Elixir', 2): Timestamp('2024-07-27 00:00:00'), ('Elixir', 3): Timestamp('2024-07-21 01:00:00'), ('Elixir', 4): Timestamp('2024-07-28 00:00:00'), ('Elixir', 5): Timestamp('2024-07-22 00:00:00'), ('Elixir', 6): Timestamp('2024-07-29 00:00:00'), ('Freedom', 1): Timestamp('2024-07-20 00:30:00'), ('Freedom', 2): Timestamp('2024-07-27 00:30:00'), ('Freedom', 3): Timestamp('2024-07-21 00:00:00'), ('Freedom', 4): Timestamp('2024-07-28 00:30:00'), ('Freedom', 5): Timestamp('2024-07-21 23:30:00'), ('Freedom', 6): Timestamp('2024-07-28 23:30:00'), ('House of Fortune', 1): Timestamp('2024-07-19 22:00:00'), ('House of Fortune', 2): Timestamp('2024-07-26 22:00:00'), ('House of Fortune', 3): Timestamp('2024-07-20 22:00:00'), ('House of Fortune', 4): Timestamp('2024-07-27 22:00:00'), ('House of Fortune', 5): Timestamp('2024-07-21 22:00:00'), ('House of Fortune', 6): Timestamp('2024-07-28 22:00:00'), ('Library', 1): Timestamp('2024-07-20 00:35:00'), ('Library', 2): Timestamp('2024-07-27 00:35:00'), ('Library', 3): Timestamp('2024-07-21 00:00:00'), ('Library', 4): Timestamp('2024-07-28 00:00:00'), ('Library', 5): Timestamp('2024-07-21 23:00:00'), ('Library', 6): Timestamp('2024-07-28 23:00:00'), ('Mainstage', 1): Timestamp('2024-07-20 00:50:00'), ('Mainstage', 2): Timestamp('2024-07-27 00:50:00'), ('Mainstage', 3): Timestamp('2024-07-21 00:50:00'), ('Mainstage', 4): Timestamp('2024-07-28 00:50:00'), ('Mainstage', 5): Timestamp('2024-07-21 23:50:00'), ('Mainstage', 6): Timestamp('2024-07-28 23:50:00'), ('Moosebar', 1): Timestamp('2024-07-19 16:00:00'), ('Moosebar', 2): Timestamp('2024-07-26 16:00:00'), ('Moosebar', 3): Timestamp('2024-07-20 16:00:00'), ('Moosebar', 4): Timestamp('2024-07-27 16:00:00'), ('Moosebar', 5): Timestamp('2024-07-21 16:00:00'), ('Moosebar', 6): Timestamp('2024-07-28 16:00:00'), ('Planaxis', 1): Timestamp('2024-07-20 00:00:00'), ('Planaxis', 2): Timestamp('2024-07-27 00:00:00'), ('Planaxis', 3): Timestamp('2024-07-21 00:00:00'), ('Planaxis', 4): Timestamp('2024-07-28 00:00:00'), ('Planaxis', 5): Timestamp('2024-07-21 23:50:00'), ('Planaxis', 6): Timestamp('2024-07-28 23:50:00'), ('Rave Cave', 1): Timestamp('2024-07-20 00:00:00'), ('Rave Cave', 2): Timestamp('2024-07-27 00:00:00'), ('Rave Cave', 3): Timestamp('2024-07-21 01:00:00'), ('Rave Cave', 4): Timestamp('2024-07-28 01:00:00'), ('Rave Cave', 5): Timestamp('2024-07-22 00:00:00'), ('Rave Cave', 6): T ...

# %%
# Convert to minutes, since pulp doesn't work with timestamps
t_close = {key: to_minutes_since_midnight(value, key[1]) for key, value in t_close.items()}
# Print the resulting T_ds
print("t_close:")
print(t_close)
# Out:
# t_close:
Novak': 39, 'Philou Louzolo': 28, 'Calussa': 48, 'Hugel': 78, 'Amémé': 48, 'Sunnery James & Ryan Marciano': 46, 'Sunnery James & Ryan Marciano b2b Philou Louzolo b2b Amémé': 46, 'BYØRN': 48, 'Novah': 38, 'LESSSS': 35, 'VIDO': 47, 'Azyr': 37, 'Trym': 0, 'Sara Landry': 60, 'Oguz': 49, 'Dyen': 31, 'Poleen': 0, 'NSI': 45, 'John Bowtie': 7, 'Stasi Sanlin': 50, 'Arado': 16, 'Afshin Momadi': 32, 'Birds Of Mind': 44, 'Ann Clue': 43, 'VTSS': 45, 'DJ Archie': 0, 'Merow': 32, 'Basstripper b2b Primate': 49, 'Harriet Jaxxon': 24, 'MONTELL2099': 42, 'Koven': 11, 'Grafix': 53, 'Kanine': 55, 'Luude': 66, 'Charlie Tee b2b Lens': 0, 'Dimension': 63, 'Bonobo b2b Dixon': 64, 'Milan Evens': 50, 'Cellini': 16, 'Dino Lenny': 37, 'Elkka': 40, 'TSHA': 51, 'Bonobo': 64, 'Dixon': 52, 'Rumix': 55, 'Neall': 25, 'Nico Parisi': 21, 'Anonymize': 7, 'Jens Lissat': 36, 'Franky Jones': 43, 'DJ Ghost': 45, 'Furax': 44, 'Franky Kloeck': 2, 'Push': 73, 'Bonzai All Stars': 16, 'Two/Three': 13, 'YULI ANA': 0, 'MCR-T': 86, 'Parkerstrange': 17, 'Klaudia Gawlas': 29, 'Parfait & Charlie Sparks': 18, 'Callush': 12, 'Yo-ki': 54, 'Kaspa': 45, 'Brits & Boen': 21, 'Los Bomberos': 0, 'Schuurrallures': 50, 'Bobby & Djenko': 0, 'Monta': 62, 'Deuxfwa': 50, 'White Noise': 84, 'Neon': 70, 'Antdot': 61, 'Alex Wann': 62, 'Dom Dolla': 71, 'Solomun b2b Four Tet': 60, 'Kenn Colt': 34, 'Stephine B': 50, 'Kryder': 49, 'PARISI (live)': 48, 'Symphony of Unity': 50, 'Salvatore Ganacci': 55, 'Sebastian Ingrosso & Steve Angello': 0, 'MORTEN': 64, 'REZZMAU5': 29, 'TBA': 22, 'Juul Pence': 50, 'Aline Rocha': 12, 'Melon Bomb': 10, 'Melvo Baptiste': 20, 'Jayda G': 51, 'Jellybean Benitez': 23, 'Alexander Merlin': 35, 'Loulou Players': 30, 'Manuals': 18, 'Cat Dealers': 58, 'Goodboys': 68, 'Sub Focus & ID': 68, 'Sam Oui': 0, 'Lavern': 70,  ...

# %%
# * Popularity score for stages
print("Parameter p_s: Popularity score for each stage")
print(p_s)
# Out:
# Parameter p_s: Popularity score for each stage
# {'Atmosphere': 48.507462686567166, 'Cage': 44.703899855560906, 'Casa Corona': 36.20606644198363, 'Core': 39.64853153586904, 'Crystal Garden': 54.429465575349056, 'Elixir': 46.58160808858931, 'Freedom': 50.60182956186809, 'House of Fortune': 54.21280693307655, 'Library': 100.0, 'Mainstage': 89.02262879152623, 'Moosebar': 17.958594126143478, 'Planaxis': 52.118440057775636, 'Rave Cave': 40.25036109773712, 'Rise': 46.846413095811265, 'Rose Garden': 68.72893596533461, 'The Gathering': 27.924891670678864}

# %%
# * Popularity score for days
print("Parameter p_d: Popularity score for each day")
print(p_d)
# Out:
# Parameter p_d: Popularity score for each day
# {1: 92.85837205300292, 2: 92.29048356565134, 3: 93.11650318361728, 4: 92.90999827912579, 5: 100.0, 6: 93.4262605403545, 7: 11.082429874376183, 8: 8.879710893133712}

# %% [markdown]
# -------

# %% [markdown]
# ## 3. Model

# %% [markdown]
# Let's first define our **decision variable**. This cell creates binary decision variables for the optimization model, where each variable represents whether a specific artist performs on a particular stage, on a specific day, and at a specific time slot. The `LpVariable.dicts` function generates these variables in the form of a dictionary, indexed by the 5-tuple `(a, k, s, d, t)`. Here:
# - `a` belongs to the set of artists, `A`, which lists all artists scheduled to perform.
# - `k` is belongs to set of sets of an artist, `K_a` is the set of sets (performances) that an artist a can perform. It accounts for multiple sets that each artist may have.
# - `s` belongs to the set of stages, `S`, where performances take place. `d` belongs to the set of days, `D`, representing the festival days. To ensure feasibility, the code iterates over only the valid stage-day pairs `(s, d)` from `T_ds.keys()`. This is because not all stages are open on all days.
# - `t` is taken from the set of valid time slots, `T_ds[(s, d)]`, which maps stage-day combinations `(s, d)` to their available starting times for performances.

# %%
# * Decision variable
x = pulp.LpVariable.dicts(
    "x",
    (
        (a, k, s, d, t)
        for a in A
        for k in K_a[a]
        for (s, d) in T_ds.keys()
        for t in T_ds[(s, d)]
    ),
    cat="Binary",
)

# %% [markdown]
# The resulting dictionary x contains binary decision variables, constrained to take values of 0 or 1. A value of 1 indicates that the artist `a` performs set `k` on stage `s`, on day `d`, starting at time `t`. For example, `x[('Artist1', 1, 'Atmosphere', 2, '12:00')]` represents whether "Artist1" performs his first set on the "Atmosphere" stage on day with id 2 starting at 12:00.

# %%
print(len(x)) # There are 11 119 200 scheduling possibilities :o
x
# Out:
# 11119200
# {('DJ Mars', 1, 'Atmosphere', 1, 720): x_('DJ_Mars',_1,_'Atmosphere',_1,_720),
#  ('DJ Mars', 1, 'Atmosphere', 1, 725): x_('DJ_Mars',_1,_'Atmosphere',_1,_725),
#  ('DJ Mars', 1, 'Atmosphere', 1, 730): x_('DJ_Mars',_1,_'Atmosphere',_1,_730),
#  ('DJ Mars', 1, 'Atmosphere', 1, 735): x_('DJ_Mars',_1,_'Atmosphere',_1,_735),
#  ('DJ Mars', 1, 'Atmosphere', 1, 740): x_('DJ_Mars',_1,_'Atmosphere',_1,_740),
#  ('DJ Mars', 1, 'Atmosphere', 1, 745): x_('DJ_Mars',_1,_'Atmosphere',_1,_745),
#  ('DJ Mars', 1, 'Atmosphere', 1, 750): x_('DJ_Mars',_1,_'Atmosphere',_1,_750),
#  ('DJ Mars', 1, 'Atmosphere', 1, 755): x_('DJ_Mars',_1,_'Atmosphere',_1,_755),
#  ('DJ Mars', 1, 'Atmosphere', 1, 760): x_('DJ_Mars',_1,_'Atmosphere',_1,_760),
#  ('DJ Mars', 1, 'Atmosphere', 1, 765): x_('DJ_Mars',_1,_'Atmosphere',_1,_765),
#  ('DJ Mars', 1, 'Atmosphere', 1, 770): x_('DJ_Mars',_1,_'Atmosphere',_1,_770),
#  ('DJ Mars', 1, 'Atmosphere', 1, 775): x_('DJ_Mars',_1,_'Atmosphere',_1,_775),
#  ('DJ Mars', 1, 'Atmosphere', 1, 780): x_('DJ_Mars',_1,_'Atmosphere',_1,_780),
#  ('DJ Mars', 1, 'Atmosphere', 1, 785): x_('DJ_Mars',_1,_'Atmosphere',_1,_785),
#  ('DJ Mars', 1, 'Atmosphere', 1, 790): x_('DJ_Mars',_1,_'Atmosphere',_1,_790),
#  ('DJ Mars', 1, 'Atmosphere', 1, 795): x_('DJ_Mars',_1,_'Atmosphere',_1,_795),
#  ('DJ Mars', 1, 'Atmosphere', 1, 800): x_('DJ_Mars',_1,_'Atmosphere',_1,_800),
#  ('DJ Mars', 1, 'Atmosphere', 1, 805): x_('DJ_Mars',_1,_'Atmosphere',_1,_805),
#  ('DJ Mars', 1, 'Atmosphere', 1, 810): x_('DJ_Mars',_1,_'Atmosphere',_1,_810),
#  ('DJ Mars', 1, 'Atmosphere', 1, 815): x_('DJ_Mars',_1,_'Atmosphere',_1,_815),
#  ('DJ Mars', 1, 'Atmosphere', 1, 820): x_('DJ_Mars',_1,_'Atmosphere',_1,_820),
#  ('DJ Mars', 1, 'Atmosphere', 1, 825): x_('DJ_Mars',_1,_'Atmosphere',_1,_825),
#  ('DJ Mars', 1, 'Atmosphere', 1, 830): x_('DJ_Mars',_1,_'Atmosphere',_1,_830),
#  ('DJ Mars', 1, 'Atmosphere', 1, 835): x_('DJ_Mars',_1,_'Atmosphere',_1,_835),
#  ('DJ Mars', 1, 'Atmosphere', 1, 840): x_('DJ_Mars',_1,_'Atmosphere',_1,_840),
#  ('DJ Mars', 1, 'Atmosphere', 1, 845): x_('DJ_Mars',_1,_'Atmosphere',_1,_845),
#  ('DJ Mars', 1, 'Atmosphere', 1, 850): x_('DJ_Mars',_1,_'Atmosphere',_1,_850),
#  ('DJ Mars', 1, 'Atmosphere', 1, 855): x_('DJ_Mars',_1,_'Atmosphere',_1,_855),
#  ('DJ Mars', 1, 'Atmosphere', 1, 860): x_('DJ_Mars',_1,_'Atmosphere',_1,_860),
#  ('DJ Mars', 1, 'Atmosphere', 1, 865): x_('DJ_Mars',_1,_'Atmosphere',_1,_865),
#  ('DJ Mars', 1, 'Atmosphere', 1, 870): x_('DJ_Mars',_1,_'Atmosphere',_1,_870),
#  ('DJ Mars', 1, 'Atmosphere', 1, 875): x_('DJ_Mars',_1,_'Atmosphere',_1,_875),
#  ('DJ Mars', 1, 'Atmosphere', 1, 880): x_('DJ_Mars',_1,_'Atmosphere',_1,_880),
#  ('DJ Mars', 1, 'Atmosphere', 1, 885): x_('DJ_Mars',_1,_'Atmosphere',_1,_885),
#  ('DJ Mars', 1, 'Atmosphere', 1, 890): x_('DJ_Mars',_1,_'Atmosphere',_1,_890),
#  ('DJ Mars', 1, 'Atmosphere', 1, 895): x_('DJ_Mars',_1,_'Atmosphere',_1,_895),
#  ('DJ Mars', 1, 'Atmosphere', 1, 900): x_('DJ_Mars',_1,_'Atmosphere',_1,_900),
#  ('DJ Mars', 1, 'Atmosphere', 1, 905): x_('DJ_Mars',_1,_'Atmosphere',_1,_905),
#  ('DJ Mars', 1, 'Atmosphere', 1, 910): x_('DJ_Mars',_1,_'Atmosphere',_1,_910),
#  ('DJ Mars', 1, 'Atmosphere', 1, 915): x_('DJ_Mars',_1,_'Atmosphere',_1,_915),
#  ('DJ Mars', 1, 'Atmosphere', 1, 920): x_('DJ_Mars',_1,_'Atmosphere',_1,_920),
#  ('DJ Mars', 1, 'Atmosphere', 1, 925): x_('DJ_Mars',_1,_'Atmosphere',_1,_925),
#  ('DJ Mars', 1, 'Atmosphere', 1, 930): x_('DJ_Mars',_1,_'Atmosphere',_1,_930),
#  ('DJ Mars', 1, 'Atmosphere', 1, 935): x_('DJ_Mars',_1,_'Atmosphere',_1,_935),
#  ('DJ Mars', 1, 'Atmosphere', 1, 940): x_('DJ_Mars',_1,_'Atmosphere',_1,_940),
#  ('DJ Mars', 1, 'Atmosphere', 1, 945): x_('DJ_Mars',_1,_'Atmosphere',_1,_945),
#  ('DJ Mars', 1, 'Atmosphere', 1, 950): x_('DJ_Mars',_1,_'Atmosphere',_1,_950),
#  ('DJ Mars', 1, 'Atmosphere', 1, 955): x_('DJ_Mars',_1,_'Atmosphere',_1,_955),
#  ('DJ Mars', 1, 'Atmosphere', 1, 960): x_('DJ_Mars',_1,_'Atmosphere',_1,_960),
#  ('DJ Mars', 1, 'Atmosphere', 1, 965): x_('DJ_Mars',_1,_'Atmosphere',_1,_965),
#  ('DJ Mars', 1, 'Atmosphere', 1, 970): x_('DJ_Mars',_1,_'Atmosphere',_1,_970),
#  ('DJ Mars', 1, 'Atmosphere', 1, 975): x_('DJ_Mars',_1,_'Atmosphere',_1,_975),
#  ('DJ Mars', 1, 'Atmosphere', 1, 980): x_('DJ_Mars',_1,_'Atmosphere',_1,_980),
#  ('DJ Mars', 1, 'Atmosphere', 1, 985): x_('DJ_Mars',_1,_'Atmosphere',_1,_985),
#  ('DJ Mars', 1, 'Atmosphere', 1, 990): x_('DJ_Mars',_1,_'Atmosphere',_1,_990),
#  ('DJ Mars', 1, 'Atmosphere', 1, 995): x_('DJ_Mars',_1,_'Atmosphere',_1,_995),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   1,
#   1000): x_('DJ_Mars',_1,_'Atmosphere',_1,_1000),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   1,
#   1005): x_('DJ_Mars',_1,_'Atmosphere',_1,_1005),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   1,
#   1010): x_('DJ_Mars',_1,_'Atmosphere',_1,_1010),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   1,
#   1015): x_('DJ_Mars',_1,_'Atmosphere',_1,_1015),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   1,
#   1020): x_('DJ_Mars',_1,_'Atmosphere',_1,_1020),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   1,
#   1025): x_('DJ_Mars',_1,_'Atmosphere',_1,_1025),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   1,
#   1030): x_('DJ_Mars',_1,_'Atmosphere',_1,_1030),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   1,
#   1035): x_('DJ_Mars',_1,_'Atmosphere',_1,_1035),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   1,
#   1040): x_('DJ_Mars',_1,_'Atmosphere',_1,_1040),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   1,
#   1045): x_('DJ_Mars',_1,_'Atmosphere',_1,_1045),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   1,
#   1050): x_('DJ_Mars',_1,_'Atmosphere',_1,_1050),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   1,
#   

#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   1,
#   1495): x_('DJ_Mars',_1,_'Atmosphere',_1,_1495),
#  ('DJ Mars', 1, 'Atmosphere', 2, 720): x_('DJ_Mars',_1,_'Atmosphere',_2,_720),
#  ('DJ Mars', 1, 'Atmosphere', 2, 725): x_('DJ_Mars',_1,_'Atmosphere',_2,_725),
#  ('DJ Mars', 1, 'Atmosphere', 2, 730): x_('DJ_Mars',_1,_'Atmosphere',_2,_730),
#  ('DJ Mars', 1, 'Atmosphere', 2, 735): x_('DJ_Mars',_1,_'Atmosphere',_2,_735),
#  ('DJ Mars', 1, 'Atmosphere', 2, 740): x_('DJ_Mars',_1,_'Atmosphere',_2,_740),
#  ('DJ Mars', 1, 'Atmosphere', 2, 745): x_('DJ_Mars',_1,_'Atmosphere',_2,_745),
#  ('DJ Mars', 1, 'Atmosphere', 2, 750): x_('DJ_Mars',_1,_'Atmosphere',_2,_750),
#  ('DJ Mars', 1, 'Atmosphere', 2, 755): x_('DJ_Mars',_1,_'Atmosphere',_2,_755),
#  ('DJ Mars', 1, 'Atmosphere', 2, 760): x_('DJ_Mars',_1,_'Atmosphere',_2,_760),
#  ('DJ Mars', 1, 'Atmosphere', 2, 765): x_('DJ_Mars',_1,_'Atmosphere',_2,_765),
#  ('DJ Mars', 1, 'Atmosphere', 2, 770): x_('DJ_Mars',_1,_'Atmosphere',_2,_770),
#  ('DJ Mars', 1, 'Atmosphere', 2, 775): x_('DJ_Mars',_1,_'Atmosphere',_2,_775),
#  ('DJ Mars', 1, 'Atmosphere', 2, 780): x_('DJ_Mars',_1,_'Atmosphere',_2,_780),
#  ('DJ Mars', 1, 'Atmosphere', 2, 785): x_('DJ_Mars',_1,_'Atmosphere',_2,_785),
#  ('DJ Mars', 1, 'Atmosphere', 2, 790): x_('DJ_Mars',_1,_'Atmosphere',_2,_790),
#  ('DJ Mars', 1, 'Atmosphere', 2, 795): x_('DJ_Mars',_1,_'Atmosphere',_2,_795),
#  ('DJ Mars', 1, 'Atmosphere', 2, 800): x_('DJ_Mars',_1,_'Atmosphere',_2,_800),
#  ('DJ Mars', 1, 'Atmosphere', 2, 805): x_('DJ_Mars',_1,_'Atmosphere',_2,_805),
#  ('DJ Mars', 1, 'Atmosphere', 2, 810): x_('DJ_Mars',_1,_'Atmosphere',_2,_810),
#  ('DJ Mars', 1, 'Atmosphere', 2, 815): x_('DJ_Mars',_1,_'Atmosphere',_2,_815),
#  ('DJ Mars', 1, 'Atmosphere', 2, 820): x_('DJ_Mars',_1,_'Atmosphere',_2,_820),
#  ('DJ Mars', 1, 'Atmosphere', 2, 825): x_('DJ_Mars',_1,_'Atmosphere',_2,_825),
#  ('DJ Mars', 1, 'Atmosphere', 2, 830): x_('DJ_Mars',_1,_'Atmosphere',_2,_830),
#  ('DJ Mars', 1, 'Atmosphere', 2, 835): x_('DJ_Mars',_1,_'Atmosphere',_2,_835),
#  ('DJ Mars', 1, 'Atmosphere', 2, 840): x_('DJ_Mars',_1,_'Atmosphere',_2,_840),
#  ('DJ Mars', 1, 'Atmosphere', 2, 845): x_('DJ_Mars',_1,_'Atmosphere',_2,_845),
#  ('DJ Mars', 1, 'Atmosphere', 2, 850): x_('DJ_Mars',_1,_'Atmosphere',_2,_850),
#  ('DJ Mars', 1, 'Atmosphere', 2, 855): x_('DJ_Mars',_1,_'Atmosphere',_2,_855),
#  ('DJ Mars', 1, 'Atmosphere', 2, 860): x_('DJ_Mars',_1,_'Atmosphere',_2,_860),
#  ('DJ Mars', 1, 'Atmosphere', 2, 865): x_('DJ_Mars',_1,_'Atmosphere',_2,_865),
#  ('DJ Mars', 1, 'Atmosphere', 2, 870): x_('DJ_Mars',_1,_'Atmosphere',_2,_870),
#  ('DJ Mars', 1, 'Atmosphere', 2, 875): x_('DJ_Mars',_1,_'Atmosphere',_2,_875),
#  ('DJ Mars', 1, 'Atmosphere', 2, 880): x_('DJ_Mars',_1,_'Atmosphere',_2,_880),
#  ('DJ Mars', 1, 'Atmosphere', 2, 885): x_('DJ_Mars',_1,_'Atmosphere',_2,_885),
#  ('DJ Mars', 1, 'Atmosphere', 2, 890): x_('DJ_Mars',_1,_'Atmosphere',_2,_890),
#  ('DJ Mars', 1, 'Atmosphere', 2, 895): x_('DJ_Mars',_1,_'Atmosphere',_2,_895),
#  ('DJ Mars', 1, 'Atmosphere', 2, 900): x_('DJ_Mars',_1,_'Atmosphere',_2,_900),
#  ('DJ Mars', 1, 'Atmosphere', 2, 905): x_('DJ_Mars',_1,_'Atmosphere',_2,_905),
#  ('DJ Mars', 1, 'Atmosphere', 2, 910): x_('DJ_Mars',_1,_'Atmosphere',_2,_910),
#  ('DJ Mars', 1, 'Atmosphere', 2, 915): x_('DJ_Mars',_1,_'Atmosphere',_2,_915),
#  ('DJ Mars', 1, 'Atmosphere', 2, 920): x_('DJ_Mars',_1,_'Atmosphere',_2,_920),
#  ('DJ Mars', 1, 'Atmosphere', 2, 925): x_('DJ_Mars',_1,_'Atmosphere',_2,_925),
#  ('DJ Mars', 1, 'Atmosphere', 2, 930): x_('DJ_Mars',_1,_'Atmosphere',_2,_930),
#  ('DJ Mars', 1, 'Atmosphere', 2, 935): x_('DJ_Mars',_1,_'Atmosphere',_2,_935),
#  ('DJ Mars', 1, 'Atmosphere', 2, 940): x_('DJ_Mars',_1,_'Atmosphere',_2,_940),
#  ('DJ Mars', 1, 'Atmosphere', 2, 945): x_('DJ_Mars',_1,_'Atmosphere',_2,_945),
#  ('DJ Mars', 1, 'Atmosphere', 2, 950): x_('DJ_Mars',_1,_'Atmosphere',_2,_950),
#  ('DJ Mars', 1, 'Atmosphere', 2, 955): x_('DJ_Mars',_1,_'Atmosphere',_2,_955),
#  ('DJ Mars', 1, 'Atmosphere', 2, 960): x_('DJ_Mars',_1,_'Atmosphere',_2,_960),
#  ('DJ Mars', 1, 'Atmosphere', 2, 965): x_('DJ_Mars',_1,_'Atmosphere',_2,_965),
#  ('DJ Mars', 1, 'Atmosphere', 2, 970): x_('DJ_Mars',_1,_'Atmosphere',_2,_970),
#  ('DJ Mars', 1, 'Atmosphere', 2, 975): x_('DJ_Mars',_1,_'Atmosphere',_2,_975),
#  ('DJ Mars', 1, 'Atmosphere', 2, 980): x_('DJ_Mars',_1,_'Atmosphere',_2,_980),

#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   2,
#   1420): x_('DJ_Mars',_1,_'Atmosphere',_2,_1420),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   2,
#   1425): x_('DJ_Mars',_1,_'Atmosphere',_2,_1425),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   2,
#   1430): x_('DJ_Mars',_1,_'Atmosphere',_2,_1430),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   2,
#   1435): x_('DJ_Mars',_1,_'Atmosphere',_2,_1435),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   2,
#   1440): x_('DJ_Mars',_1,_'Atmosphere',_2,_1440),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   2,
#   1445): x_('DJ_Mars',_1,_'Atmosphere',_2,_1445),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   2,
#   1450): x_('DJ_Mars',_1,_'Atmosphere',_2,_1450),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   2,
#   1455): x_('DJ_Mars',_1,_'Atmosphere',_2,_1455),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   2,
#   1460): x_('DJ_Mars',_1,_'Atmosphere',_2,_1460),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   2,
#   1465): x_('DJ_Mars',_1,_'Atmosphere',_2,_1465),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   2,
#   1470): x_('DJ_Mars',_1,_'Atmosphere',_2,_1470),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   2,
#   1475): x_('DJ_Mars',_1,_'Atmosphere',_2,_1475),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   2,
#   1480): x_('DJ_Mars',_1,_'Atmosphere',_2,_1480),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   2,
#   1485): x_('DJ_Mars',_1,_'Atmosphere',_2,_1485),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   2,
#   1490): x_('DJ_Mars',_1,_'Atmosphere',_2,_1490),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   2,
#   1495): x_('DJ_Mars',_1,_'Atmosphere',_2,_1495),
#  ('DJ Mars', 1, 'Atmosphere', 3, 0): x_('DJ_Mars',_1,_'Atmosphere',_3,_0),
#  ('DJ Mars', 1, 'Atmosphere', 3, 5): x_('DJ_Mars',_1,_'Atmosphere',_3,_5),
#  ('DJ Mars', 1, 'Atmosphere', 3, 10): x_('DJ_Mars',_1,_'Atmosphere',_3,_10),
#  ('DJ Mars', 1, 'Atmosphere', 3, 15): x_('DJ_Mars',_1,_'Atmosphere',_3,_15),
#  ('DJ Mars', 1, 'Atmosphere', 3, 20): x_('DJ_Mars',_1,_'Atmosphere',_3,_20),
#  ('DJ Mars', 1, 'Atmosphere', 3, 25): x_('DJ_Mars',_1,_'Atmosphere',_3,_25),
#  ('DJ Mars', 1, 'Atmosphere', 3, 30): x_('DJ_Mars',_1,_'Atmosphere',_3,_30),
#  ('DJ Mars', 1, 'Atmosphere', 3, 35): x_('DJ_Mars',_1,_'Atmosphere',_3,_35),
#  ('DJ Mars', 1, 'Atmosphere', 3, 40): x_('DJ_Mars',_1,_'Atmosphere',_3,_40),
#  ('DJ Mars', 1, 'Atmosphere', 3, 45): x_('DJ_Mars',_1,_'Atmosphere',_3,_45),
#  ('DJ Mars', 1, 'Atmosphere', 3, 50): x_('DJ_Mars',_1,_'Atmosphere',_3,_50),
#  ('DJ Mars', 1, 'Atmosphere', 3, 55): x_('DJ_Mars',_1,_'Atmosphere',_3,_55),
#  ('DJ Mars', 1, 'Atmosphere', 3, 60): x_('DJ_Mars',_1,_'Atmosphere',_3,_60),
#  ('DJ Mars', 1, 'Atmosphere', 3, 65): x_('DJ_Mars',_1,_'Atmosphere',_3,_65),
#  ('DJ Mars', 1, 'Atmosphere', 3, 70): x_('DJ_Mars',_1,_'Atmosphere',_3,_70),
#  ('DJ Mars', 1, 'Atmosphere', 3, 75): x_('DJ_Mars',_1,_'Atmosphere',_3,_75),
#  ('DJ Mars', 1, 'Atmosphere', 3, 80): x_('DJ_Mars',_1,_'Atmosphere',_3,_80),
#  ('DJ Mars', 1, 'Atmosphere', 3, 85): x_('DJ_Mars',_1,_'Atmosphere',_3,_85),
#  ('DJ Mars', 1, 'Atmosphere', 3, 90): x_('DJ_Mars',_1,_'Atmosphere',_3,_90),
#  ('DJ Mars', 1, 'Atmosphere', 3, 95): x_('DJ_Mars',_1,_'Atmosphere',_3,_95),
#  ('DJ Mars', 1, 'Atmosphere', 3, 100): x_('DJ_Mars',_1,_'Atmosphere',_3,_100),
#  ('DJ Mars', 1, 'Atmosphere', 3, 105): x_('DJ_Mars',_1,_'Atmosphere',_3,_105),
#  ('DJ Mars', 1, 'Atmosphere', 3, 110): x_('DJ_Mars',_1,_'Atmosphere',_3,_110),
#  ('DJ Mars', 1, 'Atmosphere', 3, 115): x_('DJ_Mars',_1,_'Atmosphere',_3,_115),
#  ('DJ Mars', 1, 'Atmosphere', 3, 120): x_('DJ_Mars',_1,_'Atmosphere',_3,_120),
#  ('DJ Mars', 1, 'Atmosphere', 3, 125): x_('DJ_Mars',_1,_'Atmosphere',_3,_125),
#  ('DJ Mars', 1, 'Atmosphere', 3, 130): x_('DJ_Mars',_1,_'Atmosphere',_3,_130),
#  ('DJ Mars', 1, 'Atmosphere', 3, 135): x_('DJ_Mars',_1,_'Atmosphere',_3,_135),
#  ('DJ Mars', 1, 'Atmosphere', 3, 140): x_('DJ_Mars',_1,_'Atmosphere',_3,_140),
#  ('DJ Mars', 1, 'Atmosphere', 3, 145): x_('DJ_Mars',_1,_'Atmosphere',_3,_145),
#  ('DJ Mars', 1, 'Atmosphere', 3, 150): x_('DJ_Mars',_1,_'Atmosphere',_3,_150),
#  ('DJ Mars', 1, 'Atmosphere', 3, 155): x_('DJ_Mars',_1,_'Atmosphere',_3,_155),
#  ('DJ Mars', 1, 'Atmosphere', 3, 160): x_('DJ_Mars',_1,_'Atmosphere',_3,_160),
#  ('DJ Mars', 1, 'Atmosphere', 3, 165): x_('DJ_Mars',_1,_'Atmosphere',_3,_165),
#  ('DJ Mars', 1, 'Atmosphere', 3, 170): x_('DJ_Mars',_1,_'Atmosphere',_3,_170),
#  ('DJ Mars', 1, 'Atmosphere', 3, 175): x_('DJ_Mars',_1,_'Atmosphere',_3,_175),
#  ('DJ Mars', 1, 'Atmosphere', 3, 180): x_('DJ_Mars',_1,_'Atmosphere',_3,_180),
#  ('DJ Mars', 1, 'Atmosphere', 3, 185): x_('DJ_Mars',_1,_'Atmosphere',_3,_185),
#  ('DJ Mars', 1, 'Atmosphere', 3, 190): x_('DJ_Mars',_1,_'Atmosphere',_3,_190),
#  ('DJ Mars', 1, 'Atmosphere', 3, 195): x_('DJ_Mars',_1,_'Atmosphere',_3,_195),
#  ('DJ Mars', 1, 'Atmosphere', 3, 200): x_('DJ_Mars',_1,_'Atmosphere',_3,_200),
#  ('DJ Mars', 1, 'Atmosphere', 3, 205): x_('DJ_Mars',_1,_'Atmosphere',_3,_205),
#  ('DJ Mars', 1, 'Atmosphere', 3, 210): x_('DJ_Mars',_1,_'Atmosphere',_3,_210),
#  ('DJ Mars', 1, 'Atmosphere', 3, 215): x_('DJ_Mars',_1,_'Atmosphere',_3,_215),
#  ('DJ Mars', 1, 'Atmosphere', 3, 220): x_('DJ_Mars',_1,_'Atmosphere',_3,_220),
#  ('DJ Mars', 1, 'Atmosphere', 3, 225): x_('DJ_Mars',_1,_'Atmosphere',_3,_225),
#  ('DJ Mars', 1, 'Atmosphere', 3, 230): x_('DJ_Mars',_1,_'Atmosphere',_3,_230),
#  ('DJ Mars', 1, 'Atmosphere', 3, 235): x_('DJ_Mars',_1,_'Atmosphere',_3,_235),
#  ('DJ Mars', 1, 'Atmosphere', 3, 240): x_('DJ_Mars',_1,_'Atmosphere',_3,_240),
#  ('DJ Mars', 1, 'Atmosphere', 3, 245): x_('DJ_Mars',_1,_'Atmosphere',_3,_245),
#  ('DJ Mars', 1, 'Atmosphere', 3, 250): x_('DJ_Mars',_1,_'Atmosphere',_3,_250),
#  ('DJ Mars', 1, 'Atmosphere', 3, 255): x_('DJ_Mars',_1,_'Atmosphere',_3,_255),
#  ('DJ Mars', 1, 'Atmosphere', 3, 260): x_('DJ_Mars',_1,_'Atmosphere',_3,_260),
#  ('DJ Mars', 1, 'Atmosphere', 3, 265): x_('DJ_Mars',_1,_'Atmosphere',_3,_265),
#  ('DJ Mars', 1, 'Atmosphere', 3, 270): x_('DJ_Mars',_1,_'Atmosphere',_3,_270),
#  ('DJ Mars', 1, 'Atmosphere', 3, 275): x_('DJ_Mars',_1,_'Atmosphere',_3,_275),
#  ('DJ Mars', 1, 'Atmosphere', 3, 280): x_('DJ_Mars',_1,_'Atmosphere',_3,_280),
#  ('DJ Mars', 1, 'Atmosphere', 3, 285): x_('DJ_Mars',_1,_'Atmosphere',_3,_285),
#  ('DJ Mars', 1, 'Atmosphere', 3, 290): x_('DJ_Mars',_1,_'Atmosphere',_3,_290),
#  ('DJ Mars', 1, 'Atmosphere', 3, 295): x_('DJ_Mars',_1,_'Atmosphere',_3,_295),
#  ('DJ Mars', 1, 'Atmosphere', 3, 300): x_('DJ_Mars',_1,_'Atmosphere',_3,_300),
#  ('DJ Mars', 1, 'Atmosphere', 3, 305): x_('DJ_Mars',_1,_'Atmosphere',_3,_305),
#  ('DJ Mars', 1, 'Atmosphere', 3, 310): x_('DJ_Mars',_1,_'Atmosphere',_3,_310),
#  ('DJ Mars', 1, 'Atmosphere', 3, 315): x_('DJ_Mars',_1,_'Atmosphere',_3,_315),
#  ('DJ Mars', 1, 'Atmosphere', 3, 320): x_('DJ_Mars',_1,_'Atmosphere',_3,_320),
#  ('DJ Mars', 1, 'Atmosphere', 3, 325): x_('DJ_Mars',_1,_'Atmosphere',_3,_325),
#  ('DJ Mars', 1, 'Atmosphere', 3, 330): x_('DJ_Mars',_1,_'Atmosphere',_3,_330),
#  ('DJ Mars', 1, 'Atmosphere', 3, 335): x_('DJ_Mars',_1,_'Atmosphere',_3,_335),
#  ('DJ Mars', 1, 'Atmosphere', 3, 340): x_('DJ_Mars',_1,_'Atmosphere',_3,_340),
#  ('DJ Mars', 1, 'Atmosphere', 3, 345): x_('DJ_Mars',_1,_'Atmosphere',_3,_345),
#  ('DJ Mars', 1, 'Atmosphere', 3, 350): x_('DJ_Mars',_1,_'Atmosphere',_3,_350),
#  ('DJ Mars', 1, 'Atmosphere', 3, 355): x_('DJ_Mars',_1,_'Atmosphere',_3,_355),
#  ('DJ Mars', 1, 'Atmosphere', 3, 360): x_('DJ_Mars',_1,_'Atmosphere',_3,_360),
#  ('DJ Mars', 1, 'Atmosphere', 3, 365): x_('DJ_Mars',_1,_'Atmosphere',_3,_365),
#  ('DJ Mars', 1, 'Atmosphere', 3, 370): x_('DJ_Mars',_1,_'Atmosphere',_3,_370),
#  ('DJ Mars', 1, 'Atmosphere', 3, 375): x_('DJ_Mars',_1,_'Atmosphere',_3,_375),
#  ('DJ Mars', 1, 'Atmosphere', 3, 380): x_('DJ_Mars',_1,_'Atmosphere',_3,_380),
#  ('DJ Mars', 1, 'Atmosphere', 3, 385): x_('DJ_Mars',_1,_'Atmosphere',_3,_385),
#  ('DJ Mars', 1, 'Atmosphere', 3, 390): x_('DJ_Mars',_1,_'Atmosphere',_3,_390),
#  ('DJ Mars', 1, 'Atmosphere', 3, 395): x_('DJ_Mars',_1,_'Atmosphere',_3,_395),
#  ('DJ Mars', 1, 'Atmosphere', 3, 400): x_('DJ_Mars',_1,_'Atmosphere',_3,_400),
#  ('DJ Mars', 1, 'Atmosphere', 3, 405): x_('DJ_Mars',_1,_'Atmosphere',_3,_405),
#  ('DJ Mars', 1, 'Atmosphere', 3, 410): x_('DJ_Mars',_1,_'Atmosphere',_3,_410),
#  ('DJ Mars', 1, 'Atmosphere', 3, 415): x_('DJ_Mars',_1,_'Atmosphere',_3,_415),
#  ('DJ Mars', 1, 'Atmosphere', 3, 420): x_('DJ_Mars',_1,_'Atmosphere',_3,_420),
#  ('DJ Mars', 1, 'Atmosphere', 3, 425): x_('DJ_Mars',_1,_'Atmosphere',_3,_425),
#  ('DJ Mars', 1, 'Atmosphere', 3, 430): x_('DJ_Mars',_1,_'Atmosphere',_3,_430),
#  ('DJ Mars', 1, 'Atmosphere', 3, 435): x_('DJ_Mars',_1,_'Atmosphere',_3,_435),
#  ('DJ Mars', 1, 'Atmosphere', 3, 440): x_('DJ_Mars',_1,_'Atmosphere',_3,_440),
#  ('DJ Mars', 1, 'Atmosphere', 3, 445): x_('DJ_Mars',_1,_'Atmosphere',_3,_445),
#  ('DJ Mars', 1, 'Atmosphere', 3, 450): x_('DJ_Mars',_1,_'Atmosphere',_3,_450),
#  ('DJ Mars', 1, 'Atmosphere', 3, 455): x_('DJ_Mars',_1,_'Atmosphere',_3,_455),
#  ('DJ Mars', 1, 'Atmosphere', 3, 460): x_('DJ_Mars',_1,_'Atmosphere',_3,_460),
#  ('DJ Mars', 1, 'Atmosphere', 3, 465): x_('DJ_Mars',_1,_'Atmosphere',_3,_465),
#  ('DJ Mars', 1, 'Atmosphere', 3, 470): x_('DJ_Mars',_1,_'Atmosphere',_3,_470),
#  ('DJ Mars', 1, 'Atmosphere', 3, 475): x_('DJ_Mars',_1,_'Atmosphere',_3,_475),
#  ('DJ Mars', 1, 'Atmosphere', 3, 480): x_('DJ_Mars',_1,_'Atmosphere',_3,_480),
#  ('DJ Mars', 1, 'Atmosphere', 3, 485): x_('DJ_Mars',_1,_'Atmosphere',_3,_485),
#  ('DJ Mars', 1, 'Atmosphere', 3, 490): x_('DJ_Mars',_1,_'Atmosphere',_3,_490),
#  ('DJ Mars', 1, 'Atmosphere', 3, 495): x_('DJ_Mars',_1,_'Atmosphere',_3,_495),
#  ('DJ Mars', 1, 'Atmosphere', 3, 500): x_('DJ_Mars',_1,_'Atmosphere',_3,_500),
#  ('DJ Mars', 1, 'Atmosphere', 3, 505): x_('DJ_Mars',_1,_'Atmosphere',_3,_505),
#  ('DJ Mars', 1, 'Atmosphere', 3, 510): x_('DJ_Mars',_1,_'Atmosphere',_3,_510),
#  ('DJ Mars', 1, 'Atmosphere', 3, 515): x_('DJ_Mars',_1,_'Atmosphere',_3,_515),
#  ('DJ Mars', 1, 'Atmosphere', 3, 520): x_('DJ_Mars',_1,_'Atmosphere',_3,_520),
#  ('DJ Mars', 1, 'Atmosphere', 3, 525): x_('DJ_Mars',_1,_'Atmosphere',_3,_525),
#  ('DJ Mars', 1, 'Atmosphere', 3, 530): x_('DJ_Mars',_1,_'Atmosphere',_3,_530),
#  ('DJ Mars', 1, 'Atmosphere', 3, 535): x_('DJ_Mars',_1,_'Atmosphere',_3,_535),
#  ('DJ Mars', 1, 'Atmosphere', 3, 540): x_('DJ_Mars',_1,_'Atmosphere',_3,_540),
#  ('DJ Mars', 1, 'Atmosphere', 3, 545): x_('DJ_Mars',_1,_'Atmosphere',_3,_545),
#  ('DJ Mars', 1, 'Atmosphere', 3, 550): x_('DJ_Mars',_1,_'Atmosphere',_3,_550),
#  ('DJ Mars', 1, 'Atmosphere', 3, 555): x_('DJ_Mars',_1,_'Atmosphere',_3,_555),
#  ('DJ Mars', 1, 'Atmosphere', 3, 560): x_('DJ_Mars',_1,_'Atmosphere',_3,_560),
#  ('DJ Mars', 1, 'Atmosphere', 3, 565): x_('DJ_Mars',_1,_'Atmosphere',_3,_565),
#  ('DJ Mars', 1, 'Atmosphere', 3, 570): x_('DJ_Mars',_1,_'Atmosphere',_3,_570),
#  ('DJ Mars', 1, 'Atmosphere', 3, 575): x_('DJ_Mars',_1,_'Atmosphere',_3,_575),
#  ('DJ Mars', 1, 'Atmosphere', 3, 580): x_('DJ_Mars',_1,_'Atmosphere',_3,_580),
#  ('DJ Mars', 1, 'Atmosphere', 3, 585): x_('DJ_Mars',_1,_'Atmosphere',_3,_585),
#  ('DJ Mars', 1, 'Atmosphere', 3, 590): x_('DJ_Mars',_1,_'Atmosphere',_3,_590),
#  ('DJ Mars', 1, 'Atmosphere', 3, 595): x_('DJ_Mars',_1,_'Atmosphere',_3,_595),
#  ('DJ Mars', 1, 'Atmosphere', 3, 600): x_('DJ_Mars',_1,_'Atmosphere',_3,_600),
#  ('DJ Mars', 1, 'Atmosphere', 3, 605): x_('DJ_Mars',_1,_'Atmosphere',_3,_605),
#  ('DJ Mars', 1, 'Atmosphere', 3, 610): x_('DJ_Mars',_1,_'Atmosphere',_3,_610),
#  ('DJ Mars', 1, 'Atmosphere', 3, 615): x_('DJ_Mars',_1,_'Atmosphere',_3,_615),
#  ('DJ Mars', 1, 'Atmosphere', 3, 620): x_('DJ_Mars',_1,_'Atmosphere',_3,_620),
#  ('DJ Mars', 1, 'Atmosphere', 3, 625): x_('DJ_Mars',_1,_'Atmosphere',_3,_625),
#  ('DJ Mars', 1, 'Atmosphere', 3, 630): x_('DJ_Mars',_1,_'Atmosphere',_3,_630),
#  ('DJ Mars', 1, 'Atmosphere', 3, 635): x_('DJ_Mars',_1,_'Atmosphere',_3,_635),
#  ('DJ Mars', 1, 'Atmosphere', 3, 640): x_('DJ_Mars',_1,_'Atmosphere',_3,_640),
#  ('DJ Mars', 1, 'Atmosphere', 3, 645): x_('DJ_Mars',_1,_'Atmosphere',_3,_645),
#  ('DJ Mars', 1, 'Atmosphere', 3, 650): x_('DJ_Mars',_1,_'Atmosphere',_3,_650),
#  ('DJ Mars', 1, 'Atmosphere', 3, 655): x_('DJ_Mars',_1,_'Atmosphere',_3,_655),
#  ('DJ Mars', 1, 'Atmosphere', 3, 660): x_('DJ_Mars',_1,_'Atmosphere',_3,_660),
#  ('DJ Mars', 1, 'Atmosphere', 3, 665): x_('DJ_Mars',_1,_'Atmosphere',_3,_665),
#  ('DJ Mars', 1, 'Atmosphere', 3, 670): x_('DJ_Mars',_1,_'Atmosphere',_3,_670),
#  ('DJ Mars', 1, 'Atmosphere', 3, 675): x_('DJ_Mars',_1,_'Atmosphere',_3,_675),
#  ('DJ Mars', 1, 'Atmosphere', 3, 680): x_('DJ_Mars',_1,_'Atmosphere',_3,_680),
#  ('DJ Mars', 1, 'Atmosphere', 3, 685): x_('DJ_Mars',_1,_'Atmosphere',_3,_685),
#  ('DJ Mars', 1, 'Atmosphere', 3, 690): x_('DJ_Mars',_1,_'Atmosphere',_3,_690),
#  ('DJ Mars', 1, 'Atmosphere', 3, 695): x_('DJ_Mars',_1,_'Atmosphere',_3,_695),
#  ('DJ Mars', 1, 'Atmosphere', 3, 700): x_('DJ_Mars',_1,_'Atmosphere',_3,_700),
#  ('DJ Mars', 1, 'Atmosphere', 3, 705): x_('DJ_Mars',_1,_'Atmosphere',_3,_705),
#  ('DJ Mars', 1, 'Atmosphere', 3, 710): x_('DJ_Mars',_1,_'Atmosphere',_3,_710),
#  ('DJ Mars', 1, 'Atmosphere', 3, 715): x_('DJ_Mars',_1,_'Atmosphere',_3,_715),
#  ('DJ Mars', 1, 'Atmosphere', 3, 720): x_('DJ_Mars',_1,_'Atmosphere',_3,_720),
#  ('DJ Mars', 1, 'Atmosphere', 3, 725): x_('DJ_Mars',_1,_'Atmosphere',_3,_725),
#  ('DJ Mars', 1, 'Atmosphere', 3, 730): x_('DJ_Mars',_1,_'Atmosphere',_3,_730),
#  ('DJ Mars', 1, 'Atmosphere', 3, 735): x_('DJ_Mars',_1,_'Atmosphere',_3,_735),
#  ('DJ Mars', 1, 'Atmosphere', 3, 740): x_('DJ_Mars',_1,_'Atmosphere',_3,_740),
#  ('DJ Mars', 1, 'Atmosphere', 3, 745): x_('DJ_Mars',_1,_'Atmosphere',_3,_745),
#  ('DJ Mars', 1, 'Atmosphere', 3, 750): x_('DJ_Mars',_1,_'Atmosphere',_3,_750),
#  ('DJ Mars', 1, 'Atmosphere', 3, 755): x_('DJ_Mars',_1,_'Atmosphere',_3,_755),
#  ('DJ Mars', 1, 'Atmosphere', 3, 760): x_('DJ_Mars',_1,_'Atmosphere',_3,_760),
#  ('DJ Mars', 1, 'Atmosphere', 3, 765): x_('DJ_Mars',_1,_'Atmosphere',_3,_765),
#  ('DJ Mars', 1, 'Atmosphere', 3, 770): x_('DJ_Mars',_1,_'Atmosphere',_3,_770),
#  ('DJ Mars', 1, 'Atmosphere', 3, 775): x_('DJ_Mars',_1,_'Atmosphere',_3,_775),
#  ('DJ Mars', 1, 'Atmosphere', 3, 780): x_('DJ_Mars',_1,_'Atmosphere',_3,_780),
#  ('DJ Mars', 1, 'Atmosphere', 3, 785): x_('DJ_Mars',_1,_'Atmosphere',_3,_785),
#  ('DJ Mars', 1, 'Atmosphere', 3, 790): x_('DJ_Mars',_1,_'Atmosphere',_3,_790),
#  ('DJ Mars', 1, 'Atmosphere', 3, 795): x_('DJ_Mars',_1,_'Atmosphere',_3,_795),
#  ('DJ Mars', 1, 'Atmosphere', 3, 800): x_('DJ_Mars',_1,_'Atmosphere',_3,_800),
#  ('DJ Mars', 1, 'Atmosphere', 3, 805): x_('DJ_Mars',_1,_'Atmosphere',_3,_805),
#  ('DJ Mars', 1, 'Atmosphere', 3, 810): x_('DJ_Mars',_1,_'Atmosphere',_3,_810),
#  ('DJ Mars', 1, 'Atmosphere', 3, 815): x_('DJ_Mars',_1,_'Atmosphere',_3,_815),
#  ('DJ Mars', 1, 'Atmosphere', 3, 820): x_('DJ_Mars',_1,_'Atmosphere',_3,_820),
#  ('DJ Mars', 1, 'Atmosphere', 3, 825): x_('DJ_Mars',_1,_'Atmosphere',_3,_825),
#  ('DJ Mars', 1, 'Atmosphere', 3, 830): x_('DJ_Mars',_1,_'Atmosphere',_3,_830),
#  ('DJ Mars', 1, 'Atmosphere', 3, 835): x_('DJ_Mars',_1,_'Atmosphere',_3,_835),
#  ('DJ Mars', 1, 'Atmosphere', 3, 840): x_('DJ_Mars',_1,_'Atmosphere',_3,_840),
#  ('DJ Mars', 1, 'Atmosphere', 3, 845): x_('DJ_Mars',_1,_'Atmosphere',_3,_845),
#  ('DJ Mars', 1, 'Atmosphere', 3, 850): x_('DJ_Mars',_1,_'Atmosphere',_3,_850),
#  ('DJ Mars', 1, 'Atmosphere', 3, 855): x_('DJ_Mars',_1,_'Atmosphere',_3,_855),
#  ('DJ Mars', 1, 'Atmosphere', 3, 860): x_('DJ_Mars',_1,_'Atmosphere',_3,_860),
#  ('DJ Mars', 1, 'Atmosphere', 3, 865): x_('DJ_Mars',_1,_'Atmosphere',_3,_865),
#  ('DJ Mars', 1, 'Atmosphere', 3, 870): x_('DJ_Mars',_1,_'Atmosphere',_3,_870),
#  ('DJ Mars', 1, 'Atmosphere', 3, 875): x_('DJ_Mars',_1,_'Atmosphere',_3,_875),
#  ('DJ Mars', 1, 'Atmosphere', 3, 880): x_('DJ_Mars',_1,_'Atmosphere',_3,_880),
#  ('DJ Mars', 1, 'Atmosphere', 3, 885): x_('DJ_Mars',_1,_'Atmosphere',_3,_885),
#  ('DJ Mars', 1, 'Atmosphere', 3, 890): x_('DJ_Mars',_1,_'Atmosphere',_3,_890),
#  ('DJ Mars', 1, 'Atmosphere', 3, 895): x_('DJ_Mars',_1,_'Atmosphere',_3,_895),
#  ('DJ Mars', 1, 'Atmosphere', 3, 900): x_('DJ_Mars',_1,_'Atmosphere',_3,_900),
#  ('DJ Mars', 1, 'Atmosphere', 3, 905): x_('DJ_Mars',_1,_'Atmosphere',_3,_905),
#  ('DJ Mars', 1, 'Atmosphere', 3, 910): x_('DJ_Mars',_1,_'Atmosphere',_3,_910),
#  ('DJ Mars', 1, 'Atmosphere', 3, 915): x_('DJ_Mars',_1,_'Atmosphere',_3,_915),
#  ('DJ Mars', 1, 'Atmosphere', 3, 920): x_('DJ_Mars',_1,_'Atmosphere',_3,_920),
#  ('DJ Mars', 1, 'Atmosphere', 3, 925): x_('DJ_Mars',_1,_'Atmosphere',_3,_925),
#  ('DJ Mars', 1, 'Atmosphere', 3, 930): x_('DJ_Mars',_1,_'Atmosphere',_3,_930),
#  ('DJ Mars', 1, 'Atmosphere', 3, 935): x_('DJ_Mars',_1,_'Atmosphere',_3,_935),
#  ('DJ Mars', 1, 'Atmosphere', 3, 940): x_('DJ_Mars',_1,_'Atmosphere',_3,_940),
#  ('DJ Mars', 1, 'Atmosphere', 3, 945): x_('DJ_Mars',_1,_'Atmosphere',_3,_945),
#  ('DJ Mars', 1, 'Atmosphere', 3, 950): x_('DJ_Mars',_1,_'Atmosphere',_3,_950),
#  ('DJ Mars', 1, 'Atmosphere', 3, 955): x_('DJ_Mars',_1,_'Atmosphere',_3,_955),
#  ('DJ Mars', 1, 'Atmosphere', 3, 960): x_('DJ_Mars',_1,_'Atmosphere',_3,_960),
#  ('DJ Mars', 1, 'Atmosphere', 3, 965): x_('DJ_Mars',_1,_'Atmosphere',_3,_965),
#  ('DJ Mars', 1, 'Atmosphere', 3, 970): x_('DJ_Mars',_1,_'Atmosphere',_3,_970),
#  ('DJ Mars', 1, 'Atmosphere', 3, 975): x_('DJ_Mars',_1,_'Atmosphere',_3,_975),
#  ('DJ Mars', 1, 'Atmosphere', 3, 980): x_('DJ_Mars',_1,_'Atmosphere',_3,_980),
#  ('DJ Mars', 1, 'Atmosphere', 3, 985): x_('DJ_Mars',_1,_'Atmosphere',_3,_985),
#  ('DJ Mars', 1, 'Atmosphere', 3, 990): x_('DJ_Mars',_1,_'Atmosphere',_3,_990),
#  ('DJ Mars', 1, 'Atmosphere', 3, 995): x_('DJ_Mars',_1,_'Atmosphere',_3,_995),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   3,
#   

#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   4,
#   1425): x_('DJ_Mars',_1,_'Atmosphere',_4,_1425),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   4,
#   1430): x_('DJ_Mars',_1,_'Atmosphere',_4,_1430),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   4,
#   1435): x_('DJ_Mars',_1,_'Atmosphere',_4,_1435),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   4,
#   1440): x_('DJ_Mars',_1,_'Atmosphere',_4,_1440),
#  ('DJ Mars', 1, 'Atmosphere', 5, 720): x_('DJ_Mars',_1,_'Atmosphere',_5,_720),
#  ('DJ Mars', 1, 'Atmosphere', 5, 725): x_('DJ_Mars',_1,_'Atmosphere',_5,_725),
#  ('DJ Mars', 1, 'Atmosphere', 5, 730): x_('DJ_Mars',_1,_'Atmosphere',_5,_730),
#  ('DJ Mars', 1, 'Atmosphere', 5, 735): x_('DJ_Mars',_1,_'Atmosphere',_5,_735),
#  ('DJ Mars', 1, 'Atmosphere', 5, 740): x_('DJ_Mars',_1,_'Atmosphere',_5,_740),
#  ('DJ Mars', 1, 'Atmosphere', 5, 745): x_('DJ_Mars',_1,_'Atmosphere',_5,_745),
#  ('DJ Mars', 1, 'Atmosphere', 5, 750): x_('DJ_Mars',_1,_'Atmosphere',_5,_750),
#  ('DJ Mars', 1, 'Atmosphere', 5, 755): x_('DJ_Mars',_1,_'Atmosphere',_5,_755),
#  ('DJ Mars', 1, 'Atmosphere', 5, 760): x_('DJ_Mars',_1,_'Atmosphere',_5,_760),
#  ('DJ Mars', 1, 'Atmosphere', 5, 765): x_('DJ_Mars',_1,_'Atmosphere',_5,_765),
#  ('DJ Mars', 1, 'Atmosphere', 5, 770): x_('DJ_Mars',_1,_'Atmosphere',_5,_770),
#  ('DJ Mars', 1, 'Atmosphere', 5, 775): x_('DJ_Mars',_1,_'Atmosphere',_5,_775),
#  ('DJ Mars', 1, 'Atmosphere', 5, 780): x_('DJ_Mars',_1,_'Atmosphere',_5,_780),
#  ('DJ Mars', 1, 'Atmosphere', 5, 785): x_('DJ_Mars',_1,_'Atmosphere',_5,_785),
#  ('DJ Mars', 1, 'Atmosphere', 5, 790): x_('DJ_Mars',_1,_'Atmosphere',_5,_790),
#  ('DJ Mars', 1, 'Atmosphere', 5, 795): x_('DJ_Mars',_1,_'Atmosphere',_5,_795),
#  ('DJ Mars', 1, 'Atmosphere', 5, 800): x_('DJ_Mars',_1,_'Atmosphere',_5,_800),
#  ('DJ Mars', 1, 'Atmosphere', 5, 805): x_('DJ_Mars',_1,_'Atmosphere',_5,_805),
#  ('DJ Mars', 1, 'Atmosphere', 5, 810): x_('DJ_Mars',_1,_'Atmosphere',_5,_810),
#  ('DJ Mars', 1, 'Atmosphere', 5, 815): x_('DJ_Mars',_1,_'Atmosphere',_5,_815),
#  ('DJ Mars', 1, 'Atmosphere', 5, 820): x_('DJ_Mars',_1,_'Atmosphere',_5,_820),
#  ('DJ Mars', 1, 'Atmosphere', 5, 825): x_('DJ_Mars',_1,_'Atmosphere',_5,_825),
#  ('DJ Mars', 1, 'Atmosphere', 5, 830): x_('DJ_Mars',_1,_'Atmosphere',_5,_830),
#  ('DJ Mars', 1, 'Atmosphere', 5, 835): x_('DJ_Mars',_1,_'Atmosphere',_5,_835),
#  ('DJ Mars', 1, 'Atmosphere', 5, 840): x_('DJ_Mars',_1,_'Atmosphere',_5,_840),
#  ('DJ Mars', 1, 'Atmosphere', 5, 845): x_('DJ_Mars',_1,_'Atmosphere',_5,_845),
#  ('DJ Mars', 1, 'Atmosphere', 5, 850): x_('DJ_Mars',_1,_'Atmosphere',_5,_850),
#  ('DJ Mars', 1, 'Atmosphere', 5, 855): x_('DJ_Mars',_1,_'Atmosphere',_5,_855),
#  ('DJ Mars', 1, 'Atmosphere', 5, 860): x_('DJ_Mars',_1,_'Atmosphere',_5,_860),
#  ('DJ Mars', 1, 'Atmosphere', 5, 865): x_('DJ_Mars',_1,_'Atmosphere',_5,_865),
#  ('DJ Mars', 1, 'Atmosphere', 5, 870): x_('DJ_Mars',_1,_'Atmosphere',_5,_870),
#  ('DJ Mars', 1, 'Atmosphere', 5, 875): x_('DJ_Mars',_1,_'Atmosphere',_5,_875),
#  ('DJ Mars', 1, 'Atmosphere', 5, 880): x_('DJ_Mars',_1,_'Atmosphere',_5,_880),
#  ('DJ Mars', 1, 'Atmosphere', 5, 885): x_('DJ_Mars',_1,_'Atmosphere',_5,_885),
#  ('DJ Mars', 1, 'Atmosphere', 5, 890): x_('DJ_Mars',_1,_'Atmosphere',_5,_890),
#  ('DJ Mars', 1, 'Atmosphere', 5, 895): x_('DJ_Mars',_1,_'Atmosphere',_5,_895),
#  ('DJ Mars', 1, 'Atmosphere', 5, 900): x_('DJ_Mars',_1,_'Atmosphere',_5,_900),
#  ('DJ Mars', 1, 'Atmosphere', 5, 905): x_('DJ_Mars',_1,_'Atmosphere',_5,_905),
#  ('DJ Mars', 1, 'Atmosphere', 5, 910): x_('DJ_Mars',_1,_'Atmosphere',_5,_910),
#  ('DJ Mars', 1, 'Atmosphere', 5, 915): x_('DJ_Mars',_1,_'Atmosphere',_5,_915),
#  ('DJ Mars', 1, 'Atmosphere', 5, 920): x_('DJ_Mars',_1,_'Atmosphere',_5,_920),
#  ('DJ Mars', 1, 'Atmosphere', 5, 925): x_('DJ_Mars',_1,_'Atmosphere',_5,_925),
#  ('DJ Mars', 1, 'Atmosphere', 5, 930): x_('DJ_Mars',_1,_'Atmosphere',_5,_930),
#  ('DJ Mars', 1, 'Atmosphere', 5, 935): x_('DJ_Mars',_1,_'Atmosphere',_5,_935),
#  ('DJ Mars', 1, 'Atmosphere', 5, 940): x_('DJ_Mars',_1,_'Atmosphere',_5,_940),
#  ('DJ Mars', 1, 'Atmosphere', 5, 945): x_('DJ_Mars',_1,_'Atmosphere',_5,_945),
#  ('DJ Mars', 1, 'Atmosphere', 5, 950): x_('DJ_Mars',_1,_'Atmosphere',_5,_950),
#  ('DJ Mars', 1, 'Atmosphere', 5, 955): x_('DJ_Mars',_1,_'Atmosphere',_5,_955),
#  ('DJ Mars', 1, 'Atmosphere', 5, 960): x_('DJ_Mars',_1,_'Atmosphere',_5,_960),
#  ('DJ Mars', 1, 'Atmosphere', 5, 965): x_('DJ_Mars',_1,_'Atmosphere',_5,_965),
#  ('DJ Mars', 1, 'Atmosphere', 5, 970): x_('DJ_Mars',_1,_'Atmosphere',_5,_970),
#  ('DJ Mars', 1, 'Atmosphere', 5, 975): x_('DJ_Mars',_1,_'Atmosphere',_5,_975),
#  ('DJ Mars', 1, 'Atmosphere', 5, 980): x_('DJ_Mars',_1,_'Atmosphere',_5,_980),
#  ('DJ Mars', 1, 'Atmosphere', 5, 985): x_('DJ_Mars',_1,_'Atmosphere',_5,_985),
#  ('DJ Mars', 1, 'Atmosphere', 5, 990): x_('DJ_Mars',_1,_'Atmosphere',_5,_990),
#  ('DJ Mars', 1, 'Atmosphere', 5, 995): x_('DJ_Mars',_1,_'Atmosphere',_5,_995),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   5,
#   1000): x_('DJ_Mars',_1,_'Atmosphere',_5,_1000),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   5,
#   1005): x_('DJ_Mars',_1,_'Atmosphere',_5,_1005),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   5,
#   1010): x_('DJ_Mars',_1,_'Atmosphere',_5,_1010),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   5,
#   1015): x_('DJ_Mars',_1,_'Atmosphere',_5,_1015),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   5,
#   1020): x_('DJ_Mars',_1,_'Atmosphere',_5,_1020),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   5,
#   1025): x_('DJ_Mars',_1,_'Atmosphere',_5,_1025),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   5,
#   1030): x_('DJ_Mars',_1,_'Atmosphere',_5,_1030),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   5,
#   1035): x_('DJ_Mars',_1,_'Atmosphere',_5,_1035),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   5,
#   1040): x_('DJ_Mars',_1,_'Atmosphere',_5,_1040),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   5,
#   1045): x_('DJ_Mars',_1,_'Atmosphere',_5,_1045),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   5,
#   1050): x_('DJ_Mars',_1,_'Atmosphere',_5,_1050),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   5,
#   1055): x_('DJ_Mars',_1,_'Atmosphere',_5,_1055),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   5,
#   1060): x_('DJ_Mars',_1,_'Atmosphere',_5,_1060),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   5,
#   1065): x_('DJ_Mars',_1,_'Atmosphere',_5,_1065),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   5,
#   1070): x_('DJ_Mars',_1,_'Atmosphere',_5,_1070),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   5,
#   1075): x_('DJ_Mars',_1,_'Atmosphere',_5,_1075),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   5,
#   1080): x_('DJ_Mars',_1,_'Atmosphere',_5,_1080),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   5,
#   1085): x_('DJ_Mars',_1,_'Atmosphere',_5,_1085),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   5,
#   1090): x_('DJ_Mars',_1,_'Atmosphere',_5,_1090),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   5,
#   1095): x_('DJ_Mars',_1,_'Atmosphere',_5,_1095),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   5,
#   1100): x_('DJ_Mars',_1,_'Atmosphere',_5,_1100),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   5,
#   1105): x_('DJ_Mars',_1,_'Atmosphere',_5,_1105),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   5,
#   1110): x_('DJ_Mars',_1,_'Atmosphere',_5,_1110),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   5,
#   1115): x_('DJ_Mars',_1,_'Atmosphere',_5,_1115),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   5,
#   1120): x_('DJ_Mars',_1,_'Atmosphere',_5,_1120),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   5,
#   1125): x_('DJ_Mars',_1,_'Atmosphere',_5,_1125),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   5,
#   1130): x_('DJ_Mars',_1,_'Atmosphere',_5,_1130),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   5,
#   1135): x_('DJ_Mars',_1,_'Atmosphere',_5,_1135),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   5,
#   1140): x_('DJ_Mars',_1,_'Atmosphere',_5,_1140),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   5,
#   1145): x_('DJ_Mars',_1,_'Atmosphere',_5,_1145),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   5,
#   1150): x_('DJ_Mars',_1,_'Atmosphere',_5,_1150),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   5,
#   1155): x_('DJ_Mars',_1,_'Atmosphere',_5,_1155),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   5,
#   1160): x_('DJ_Mars',_1,_'Atmosphere',_5,_1160),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   5,
#   1165): x_('DJ_Mars',_1,_'Atmosphere',_5,_1165),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   5,
#   1170): x_('DJ_Mars',_1,_'Atmosphere',_5,_1170),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   5,
#   1175): x_('DJ_Mars',_1,_'Atmosphere',_5,_1175),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   5,
#   1180): x_('DJ_Mars',_1,_'Atmosphere',_5,_1180),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   5,
#   1185): x_('DJ_Mars',_1,_'Atmosphere',_5,_1185),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   5,
#   1190): x_('DJ_Mars',_1,_'Atmosphere',_5,_1190),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   5,
#   1195): x_('DJ_Mars',_1,_'Atmosphere',_5,_1195),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   5,
#   1200): x_('DJ_Mars',_1,_'Atmosphere',_5,_1200),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   5,
#   1205): x_('DJ_Mars',_1,_'Atmosphere',_5,_1205),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   5,
#   1210): x_('DJ_Mars',_1,_'Atmosphere',_5,_1210),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   5,
#   1215): x_('DJ_Mars',_1,_'Atmosphere',_5,_1215),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   5,
#   1220): x_('DJ_Mars',_1,_'Atmosphere',_5,_1220),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   5,
#   1225): x_('DJ_Mars',_1,_'Atmosphere',_5,_1225),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   5,
#   1230): x_('DJ_Mars',_1,_'Atmosphere',_5,_1230),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   5,
#   1235): x_('DJ_Mars',_1,_'Atmosphere',_5,_1235),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   5,
#   1240): x_('DJ_Mars',_1,_'Atmosphere',_5,_1240),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   5,
#   1245): x_('DJ_Mars',_1,_'Atmosphere',_5,_1245),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   5,
#   1250): x_('DJ_Mars',_1,_'Atmosphere',_5,_1250),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   5,
#   1255): x_('DJ_Mars',_1,_'Atmosphere',_5,_1255),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   5,
#   1260): x_('DJ_Mars',_1,_'Atmosphere',_5,_1260),
#  ('DJ Mars',
#   1,
#   'Atmosphere',
#   5,
#   1265): x_('DJ_Mars',_1,_'Atmosphere',_5,_1265),
#  ...}

# %% [markdown]
# Secondly, our **decision function** that maximizes statisfaction is defined. This code defines the optimization problem "Tomorrowland_Scheduling" as a linear programming model using the PuLP library, where the goal is to maximize satisfaction.
# - The objective function sums the weighted satisfaction scores for all possible combinations of artists, their sets, stages, days, and time slots. Specifically, the satisfaction score for each combination is calculated as the sum of three components: `p_a[a]` (artist-specific popularity), `p_s[s]` (stage-specific popularity), and `p_d[d]` (day-specific popularity). These values are then multiplied by the binary decision variable `x[(a, k, s, d, t)]`, which indicates whether artist a performs set k on stage s, on day d, at time t.
# - The use of lpSum ensures that all valid combinations of indices `(a, k, s, d, t)` — as defined by the sets `A` (artists), `K_a[a]` (sets per artist), `T_ds.keys()` (valid stage-day pairs), and `T_ds[(s, d)]` (time slots for each stage-day pair) — are included in the summation.
# - Finally, the problem is labeled "Maximize_Satisfaction" to clarify its objective within the model.

# %%
# * Decision Function
# Define the problem
problem = pulp.LpProblem("Tomorrowland_Scheduling", pulp.LpMaximize)

# Objective function
# TODO Weights?
# TODO Popularity of timeslots?
problem += pulp.lpSum(
    [
        (p_a[a] + p_s[s] + p_d[d]) * x[(a, k, s, d, t)]
        for a in A
        for k in K_a[a]
        for (s, d) in T_ds.keys()
        for t in T_ds[(s, d)]
    ]
), "Maximize_Satisfaction"
print("Finished defining the decision function.")
# Out:
# Finished defining the decision function.

# %% [markdown]
# Lastly, we define the constraints.

# %%
# * Define b_k per artist
b = { (a, k): pulp.LpVariable(f"b_{a}_{k}", cat="Continuous") for a in A for k in K_a[a] }
# Ensure b[a,k] aligns with the time slot t where x is 1 for the artist a and their set k.
for a in A:
    for k in K_a[a]:
        problem += (
            b[a, k] == pulp.lpSum(t * x[(a, k, s, d, t)] for s, d in T_ds.keys() for t in T_ds[(s, d)]),
            f"Link_bk_to_x_{a}_{k}"
        )

# %%
# * Constraint: Each set is scheduled exactly one
for a in A:
    for k in K_a[a]:
        problem += (
            pulp.lpSum(x[(a, k, s, d, t)] for s, d in T_ds.keys() for t in T_ds[(s, d)]) == 1,
            f"Unique_Assignment_{a}_{k}"
        )

# %%
# * Constraint: Each set is scheduled within stage availability
for a in A:
    for k in K_a[a]:
        for (s, d) in T_ds.keys():
            problem += (
                b[a, k] >= t_open[(s, d)],
                f"Stage_Open_Time_{a}_{k}_{s}_{d}"
            )
            problem += (
                b[a, k] + e_k[k] <= t_close[(s, d)],
                f"Stage_Close_Time_{a}_{k}_{s}_{d}"
            )

# %% [markdown]
# The big-M approach introduces a binary decision variable $y$ for each pair $(k,k′)$. This binary variable $y$ ensures that one of the two conditions holds:
# - If $y=1$, enforce Condition 1 ($k$ finishes before $k'$ starts). Condition 1: $b[a,k] + e[k] + c <= b[a', k'] + M * (1-y)$
#     - If $y=1$, the term $M * (1-y)$ becomes 0, and the constraint ensures that $k$ finishes before $k'$ starts.
#     - If $y=0$, the first constraint becomes non-binding because the constraint $b[a,k] + e[k] + c <= b[a', k'] + M * (1-y)$ always holds for a sufficiently large M.
# - If $y=0$, enforce Condition 2 ($k'$ finishes before $k$ starts). Condition 2: $b[a',k'] + e[k'] + c <= b[a, k] + M * (1-y)$
#     - If $y=1$, the second constraint becomes non-binding because the constraint  $b[a',k'] + e[k'] + c <= b[a, k] + M * (1-y)$ always holds for a sufficiently large M.
#     - If $y=0$,  the term $M * (1-y)$ becomes 0, and the constraint ensures that $k'$ finishes before $k$ starts.

# %%
# * Constraint: No 2 sets on the same stage are scheduled at the same time + clean up time
M = 2000
for (s, d) in T_ds.keys():
    for a in A:
        for k in K_a[a]:
            for a_prime in A:
                for k_prime in K_a[a_prime]:
                    if (a, k) != (a_prime, k_prime):
                        # Binary variable for either-or condition
                        y = pulp.LpVariable(f"y_{a}_{k}_{a_prime}_{k_prime}_{s}_{d}", cat="Binary")

                        # Condition 1: k finishes before k accent
                        problem += (
                            b[a, k] + e_k[k] + c <= b[a_prime, k_prime] + M * (1 - y),
                            f"NonOverlap_Condition1_{a}_{k}_{a_prime}_{k_prime}_{s}_{d}"
                        )

                        # Condition 2: k accent finishes before k
                        problem += (
                            b[a_prime, k_prime] + e_k[k_prime] + c <= b[a, k] + M * y,
                            f"NonOverlap_Condition2_{a}_{k}_{a_prime}_{k_prime}_{s}_{d}"
                        )
# Out:
# Starting defining the constraints.

# %%
print("hey")

# %% [markdown]
# -------

# %% [markdown]
# ## 4. Results

# %%
# Solve the problem
# solver = pulp.PULP_CBC_CMD()
# problem.solve(solver)

# %%
# Output the results
# print("Status:", pulp.LpStatus[problem.status])
# for v in problem.variables():
#     if v.varValue > 0:
#         print(v.name, "=", v.varValue)
#
# print("Objective Value:", pulp.value(problem.objective))
